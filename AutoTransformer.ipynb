# %%
from myclass import *

# %%
# warnings.filterwarnings("ignore", category=DeprecationWarning) 
# warnings.filterwarnings('ignore')

#################################################
#------------------ Load Data ------------------#
#################################################

patient_info = pd.read_excel('Dataset.xlsx','patient_information',engine='openpyxl')
cnv_5mb_counts = pd.read_excel('Dataset.xlsx','cnv_5mb_counts',engine='openpyxl').loc[:,['patientID','cnv_Count']].rename(columns={'cnv_Count': 'cnv_Count_5mb'})
cnv_gistic_counts = pd.read_excel('Dataset.xlsx','cnv_gistic_counts',engine='openpyxl').loc[:,['patientID','cnv_Count']].rename(columns={'cnv_Count': 'cnv_Count_gistic'})
snv = pd.read_excel('Dataset.xlsx','snv_feature_matrix',engine='openpyxl')
clinical_info = pd.read_excel('Clinical Feature.xlsx','Supplementary Table 2',engine='openpyxl').drop(['Subject type', 'Subject group', 'Stage (AJCC v7)', 'Pack-years'], axis=1)
clinical_info = clinical_info.rename(columns={'Histology':'Histology label'})

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

seed = 1105
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ## Data

# %%
##################################################
#-------------- Data Preprocessing -------------#
################################################

#----- Parameters -----#
num_patients_train = len(patient_info[patient_info.split_info == 'training'])# number of patients in training set
num_patients_test = len(patient_info[patient_info.split_info == 'validation'])# number of patients in training set
max_variats = 84 # max number of variation for each patient
num_steps = max_variats
num_feature_not_snv = 8
num_var_attri = snv.shape[1] # number of attributes to discribe each variation
scale = Normalization('MinMaxLogScale') # choose normalizer

#----- OneHot categorical variable of SNV-----#
snv['gene'] = deepcopy(snv['Gene']) # prepare for gene_snv
one_hot,_,_ = OneHotText(snv['Gene'])
snv['Gene'] = [one_hot[i] for i in range(len(one_hot))]

one_hot,_,_ = OneHotText(snv['Variant.type'])
snv['Variant.type'] = [one_hot[i] for i in range(len(one_hot))]
len_feature = {'Variant.type': len(one_hot[0])}

snv['BaseConversion'] = snv['Tumor.allele']+snv['Ref..allele']
one_hot,_,_ = OneHotText(snv['BaseConversion'])
snv['BaseConversion'] = [one_hot[i] for i in range(len(one_hot))]
len_feature['BaseConversion'] = len(one_hot[0])

one_hot,_,_ = OneHotText(snv['Chr'])
snv['Chr'] = [one_hot[i] for i in range(len(one_hot))]
len_feature['Chr'] = len(one_hot[0])

one_hot,_,_ = OneHotText(snv['germline_reads'])
snv['germline_reads'] = [one_hot[i] for i in range(len(one_hot))]
len_feature['germline_reads'] = len(one_hot[0])

# drop coded feature
snv = snv.drop(['Tumor.allele', 'Ref..allele', 'variant', 'lookup', 
                'Case', 'cohort', 'A>CUnstranded', 'A>GUnstranded',
                'A>TUnstranded', 'C>AUnstranded', 'C>GUnstranded', 
                'G>AUnstranded', 'pass_basic_QC', 'blacklist1_oncogenes',
                'pass_basic_QC_coding'], axis=1)

# snv feature list to scale
list_to_normalization = ['Position','Percent.mutant.allele', 'variant_count_norm','ontarget_shoulder_tile_mut_count_norm', 
                         'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p',
                         'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases',
                         'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth','gnomad_maxAF',
                         'size_selected_adjustment','germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval',
                         'sum_log10_frag_size_enrich_score', 'germline_depth_at_position', 'cosmic_total_count', 'cosmic_lung_count']

# %%
#----- OneHot categorical variable of clinical features ----#
one_hot,_,_ = OneHotText(clinical_info['Sex'])
clinical_info['Sex'] = deepcopy(one_hot)

one_hot,_,_ = OneHotText(clinical_info['Histology label'])
clinical_info['Histology label'] = deepcopy(one_hot)

one_hot,_,_ = OneHotText(clinical_info['Smoker'])
clinical_info['Smoker'] = deepcopy(one_hot)

# %%
x = patient_info.set_index('patientID').\
join(cnv_5mb_counts.set_index('patientID')).join(cnv_gistic_counts.set_index('patientID')).drop('SampleID', axis=1).\
join(clinical_info.set_index('Patient ID'))
num_patients = len(x)

# %%
#----- snv normalization -----#
snv_group = np.array(snv.drop(['Gene'], axis=1).groupby('patientID'),dtype = object)
list_gene = unique(snv['gene'])
gene_snv_columns = ['Variant.type', 'Chr', 'Position', 'Percent.mutant.allele', 'variant_count_norm',
       'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes',
       'duplex_reads', 'germline_NumNonZeroMeanAF_Pval',
       'mean_bc_family_size', 'watsoncrickfisher.p',
       'mean_total_bc_errors_corrected', 'mean_norm_varpos',
       'mean_var_phred_score', 'mean_num_non_ref_bases',
       'fraction_MapQmin30', 'variant_norm_bc_fam_size',
       'normalized_depth', 'gnomad_maxAF', 'base_change_transition',
       'size_selected_adjustment', 'LUNG_driver',
       'pass_basic_QC_nonsynon_lungdriver',
       'pass_basic_QC_nonsynon_lungdriver_hotspot',
       'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval',
       'sum_log10_frag_size_enrich_score', 'germline_reads',
       'germline_depth_at_position', 'tumor_adjudicated',
       'cosmic_total_count', 'has_matched_tumor',
       'intersect_unpadded_selector', 'cosmic_lung_count',
       'blacklist3tumorsupressor', 'BaseConversion']

zero_snv_feature = []
for i in gene_snv_columns:
    if i in len_feature.keys():
        zero_snv_feature.append([0 for _ in range(len_feature[i])])
    else:
        zero_snv_feature.append(0)
zero_snv_feature = [zero_snv_feature for i in range(len(list_gene))]

x['gene_snv'] = [pd.DataFrame(zero_snv_feature, index=list_gene, columns=gene_snv_columns) for i in range(num_patients)] # fill snv with 0

for i in range(len(snv_group)):
    patient_id = snv_group[i][0]
    # count and check the snv for each gene
    count = Counter(snv_group[i][1]['gene'])
    count = pd.DataFrame(count,index=['frequency']).T
    if any(count['frequency'] > 1):
        gene = count.index[count['frequency'] > 1]
        # reserve the snv with highest 'Percent.mutant.allele'
        for j in range(len(gene)):
            index_repeat_gene = snv_group[i][1]['gene'] == gene[j]
            index_to_drop = argsort(snv_group[i][1][index_repeat_gene]['Percent.mutant.allele']).index[1:]
            snv_group[i][1] = snv_group[i][1].drop(index = index_to_drop)  
    # fill the snv with gene_snv_feature
    gene_snv = snv_group[i][1]['gene']
    gene_snv_feature = snv_group[i][1].drop(['patientID', 'gene'], axis=1)
    x.loc[patient_id,'gene_snv'].loc[gene_snv] = gene_snv_feature.values

x['gene_snv_matrix']= [FlattenSNV(x['gene_snv'][i]) for i in range(num_patients)] 
# x['gene_snv_matrix']= [np.column_stack((FlattenSNV(x['gene_snv'][i]),np.zeros(192))) for i in range(num_patients)]    
snv = snv.drop('gene', axis=1)

# %%
##################################################
#-------------- Obtain Training Set -------------#
################################################
train_x = deepcopy(x[x.split_info == 'training'])

#----- clinical features normalization -----#
clinical_list_to_normalization = ['Age (years)', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)']
train_x = normalizer(train_x, clinical_list_to_normalization, scale)
#----- cnv normalization -----#
cnv_list_to_normalization = ['cnv_Count_5mb','cnv_Count_gistic']
train_x = normalizer(train_x, cnv_list_to_normalization, scale)
#----- snv normalization -----#
train_snv = deepcopy(snv[['SU2'not in i for i in snv['patientID']]])
train_snv = normalizer(train_snv, list_to_normalization, scale)
train_x = GroupAndExtractSNV(train_x, train_snv, num_steps)
    
#----- Label -----#    
train_x['label'] = [1 if 'LUP' in train_x.index[i] else 0 for i in range(train_x.shape[0])]
one_hot,_,_ = OneHotText(train_x['Stage_group'])
train_x['stage_label'] = [one_hot[i] for i in range(len(one_hot))]
train_x = train_x.drop(['Stage_group'], axis=1)

# %%
##################################################
#-------------- Obtain Test Set -------------#
################################################

test_x = deepcopy(x[x.split_info == 'validation'])

#----- clinical features normalization -----#
test_x = normalizer(test_x, clinical_list_to_normalization, scale)
#----- cnv normalization -----#
test_x = normalizer(test_x, cnv_list_to_normalization, scale)
#----- snv normalization -----#
test_snv = deepcopy(snv[['SU2' in i for i in snv['patientID']]])
test_snv = normalizer(test_snv, list_to_normalization, scale)
test_x = GroupAndExtractSNV(test_x, test_snv, num_steps)
    
#----- Label -----#    
test_x['label'] = [1 if 'SU2CS' in test_x.index[i] else 0 for i in range(test_x.shape[0])]
one_hot,_,_ = OneHotText(test_x['Stage_group'])
test_x['stage_label'] = [one_hot[i] for i in range(len(one_hot))]
test_x = test_x.drop(['Stage_group'], axis=1)

# %%
train_x_org = deepcopy(train_x)
test_x_org = deepcopy(test_x)

# %% [markdown]
# # AutoML based on Baysian optimization

# %%
class AutoTransformer(nn.Module):
    """
    Class description: only Dropout on LSTM & FC no batch norm, bidirectional Long Short-term memory model
    
    """
    #----- Define all layers -----#
    def __init__(self, fc_dropout, num_feature_not_snv, num_output_nodes, num_fc_layers, device, 
                 head, trsf_num_layer, trsf_dropout, trsf_hidden, shape, act = nn.Sigmoid(), **kwargs):
        super(AutoTransformer, self).__init__(**kwargs)
        
        #--- Transformer ---#
        # TOD0: trsf_hidden_dim
        len_sentence,trsf_imput_dim, trsf_hidden_dim  = shape[0], shape[1], trsf_hidden*head
        
        self.attention_model = AttentionModel(d_input=trsf_imput_dim, d_model=trsf_hidden_dim, d_ff=2*trsf_hidden_dim, head=head, 
                                              num_layer=trsf_num_layer, dropout=trsf_dropout)
        self.trsf_fc = nn.Linear(trsf_hidden_dim, 1)        
        
        for p in self.attention_model.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)     
        
        #--- Fully connected layers ---#
        self.num_fc_layers = num_fc_layers
        num_fc_input =  num_feature_not_snv+len_sentence
        if num_fc_layers == 1:
            self.fc0 = nn.Linear(num_fc_input, num_output_nodes)
        else:
            # the first fc layer
            self.fc0 = nn.Linear(num_fc_input, int(ceil(num_fc_input/2)))
            self.dropout0 = nn.Dropout(1.1*fc_dropout)
            if num_fc_layers == 2:
                # the last fc layer when num_fc_layers == 2
                self.fc1 = nn.Linear(int(ceil(num_fc_input/2)), num_output_nodes)
            else:
                # the middle fc layer
                for i in range(1,num_fc_layers-1):
                    tmp_input = int(ceil(num_fc_input/2**i))
                    tmp_output = int(ceil(num_fc_input/2**(i+1)))
                    exec('self.fc{} = nn.Linear(tmp_input, tmp_output)'.format(i))
                    if i < ceil(num_fc_layers/2) and 1.1**(i+1)*fc_dropout < 1:
                        exec('self.dropout{} = nn.Dropout(1.1**(i+1)*fc_dropout)'.format(i))
                    elif i >= ceil(num_fc_layers/2) and 1.1**(num_fc_layers-1-i)*fc_dropout < 1:
                        exec('self.dropout{} = nn.Dropout(1.1**(num_fc_layers-1-i)*fc_dropout)'.format(i))
                    else:
                        exec('self.dropout{} = nn.Dropout(0.5)'.format(i))
                # the last fc layer
                exec('self.fc{} = nn.Linear(tmp_output, num_output_nodes)'.format(i+1))
            
        #--- Activation function ---#
        self.act = act
    
    #----- Forward -----#
    def forward(self, x_snv, x_other):
        
        #--- Transformer layer ---#
        trsf_output = torch.squeeze(self.trsf_fc(self.attention_model(x_snv)))
        
        #--- Fully connected layers ---#
        hidden_dense = torch.cat((x_other, trsf_output), dim = 1)
        if self.num_fc_layers == 1:
            outputs = self.fc0(hidden_dense)
        else:
            # the first fc layer
            outputs = self.act(self.dropout0(self.fc0(hidden_dense)))
            if self.num_fc_layers == 2:
                # the last fc layer when num_fc_layers == 2
                outputs = self.fc1(outputs)
            else:
                # the middle fc layer
                for i in range(1,self.num_fc_layers-1):
                    outputs = eval('self.act(self.dropout{}(self.fc{}(outputs)))'.format(i,i))
                # the last fc layer
                outputs = eval('self.fc{}(outputs)'.format(i+1))
            
        return outputs.softmax(dim=1)

# %%
def train_val_test(fc_dropout, num_feature_not_snv, num_fc_layers, batch_size, lr, patience, 
                   num_outer_split, frac_inner_val, train_x, num_epochs, device, head, trsf_num_layer, trsf_dropout, trsf_hidden):
    shape = train_x['snv'][0].shape
    train_kf = []
    val_kf = []
    test_kf = []
    KF = StratifiedKFold(num_outer_split, shuffle=True)
    for train_index, sub_test_index in KF.split(train_x, train_x['label']):
        sub_train_index, sub_val_index = next(StratifiedShuffleSplit(n_splits=1,test_size=frac_inner_val).
                                               split(train_x.iloc[train_index],train_x.iloc[train_index]['label']))

        #---  Seperate traing set, validation set and test set ---#
        sub_train = Resampler(train_x.iloc[sub_train_index][:], train_x.iloc[sub_train_index]['label'])
        train_iter = BatchDataGeneration(sub_train, batch_size, shuffle=True)
        val_iter = BatchDataGeneration(train_x.iloc[sub_val_index][:], batch_size, shuffle=True)
        test_iter = BatchDataGeneration(train_x.iloc[sub_test_index][:], batch_size, shuffle=True)


        #-----  Instantiate model -----#
        model = AutoTransformer(fc_dropout, num_feature_not_snv, num_output_nodes, num_fc_layers, device, 
                                     head, trsf_num_layer, trsf_dropout, trsf_hidden, shape)
        model = model.to(device)

        model.apply(init_weights)

        #-----  Loss -----#
        loss = nn.CrossEntropyLoss(reduction="none")
        loss = loss.to(device)

        #--- Define optimizer ---#
        optimizer = torch.optim.Adam(model.parameters(), lr)
        
        #-----  Instantiate EarlyStopping -----#
        early_stopping = EarlyStopping(patience, verbose=False)

        train_loss, train_acc, train_auc, train_speed, val_loss, val_acc, val_auc = train_evaluate(
            model, train_iter, val_iter, loss, optimizer, early_stopping, num_epochs, device)
        
        model.eval()
        test_loss, test_acc, test_auc = evaluate(model, test_iter, loss, device)
        train_kf.append([train_loss, train_acc, train_auc, train_speed])
        val_kf.append([val_loss, val_acc, val_auc])
        test_kf.append([test_loss, test_acc, test_auc])
    return train_kf, val_kf, test_kf

# %%
# ---------------------------------------------------#   
#    Parameter Tuning with Bayesian optimization    #
#--------------------------------------------------# 
num_outer_split = 5
frac_inner_val = 0.25
num_output_nodes, num_epochs = 2, 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


lstm_bidirectional = True
best_score = 100
batch_size = 64
snv_to_select = snv.drop('patientID', axis=1).columns
other_feature_to_select = train_x.drop(['split_info', 'Histology label', 'label', 'stage_label', 'snv','gene_snv','gene_snv_matrix'], axis=1).columns
num_feature_to_select = len(snv_to_select) + len(other_feature_to_select)



##---   Define search space   ---##
# The list of hyper-parameters we want to optimize. For each one we define the
# bounds, the corresponding parameter name, as well as how to
# sample values from that dimension (`'log-uniform'` for the learning rate)

search_spaces = [Integer(1,2**10-1, name = 'first_group_selected_features'),
                 Integer(1,2**10-1, name = 'second_group_selected_features'),
                 Integer(1,2**10-1, name = 'third_group_selected_features'),
                 Integer(1,2**7-1, name = 'forth_group_selected_features'),
                 Integer(1,2**9-1, name = 'other_selected_features'),
                 Real(1e-1, 0.5, prior='log-uniform', name = 'fc_dropout'),
                 Real(1e-3, 1e-1, prior='log-uniform', name = 'lr'),
                 Integer(1,10, name = 'patience'),
                 Integer(1,10, name = 'num_fc_layers'),
                 Categorical([2,4,6,8,10], name = 'head'),
                 Integer(1,10, name = 'trsf_num_layer'),
                 Real(1e-1, 0.5, prior='log-uniform', name = 'trsf_dropout'),
                 Integer(1,10, name = 'trsf_hidden'),
                ]

@use_named_args(search_spaces)
def masked_objective(first_group_selected_features, second_group_selected_features, third_group_selected_features, forth_group_selected_features,
                     other_selected_features, fc_dropout, lr, patience, num_fc_layers, head, trsf_num_layer, trsf_dropout, trsf_hidden):
    global best_score, snv_to_select, other_feature_to_select
#     print(num_feature_to_select)
    #---   Decoding feature selection results   ---#
    bin_selected_features = bin(first_group_selected_features)[2:]
    for i in range(10-len(bin_selected_features)):
        bin_selected_features = '0' + bin_selected_features
        
    tmp_bin_selected_features = bin(second_group_selected_features)[2:]
    for i in range(10-len(tmp_bin_selected_features)):
        tmp_bin_selected_features = '0' + tmp_bin_selected_features
    bin_selected_features = bin_selected_features+ tmp_bin_selected_features
    
    tmp_bin_selected_features = bin(third_group_selected_features)[2:]
    for i in range(10-len(tmp_bin_selected_features)):
        tmp_bin_selected_features = '0' + tmp_bin_selected_features
    bin_selected_features = bin_selected_features+ tmp_bin_selected_features
    
    tmp_bin_selected_features = bin(forth_group_selected_features)[2:]
    for i in range(7-len(tmp_bin_selected_features)):
        tmp_bin_selected_features = '0' + tmp_bin_selected_features
    bin_selected_features = bin_selected_features+ tmp_bin_selected_features
    
    snv_selected = [snv_to_select[i] for i in range(len(snv_to_select)) if bin_selected_features[i] == '1']
    snv_selected.append('patientID')
    
    bin_selected_features = bin(other_selected_features)[2:]
    for i in range(9-len(bin_selected_features)):
        bin_selected_features = '0' + bin_selected_features
    other_feature_selected = [other_feature_to_select[i] for i in range(len(other_feature_to_select)) if bin_selected_features[i] == '1']
    other_feature_selected.append('label')
    
    new_train_snv = deepcopy(train_snv[snv_selected])
    new_train_x = deepcopy(train_x[other_feature_selected])
    new_train_x = NewGroupAndExtractSNV(new_train_x, new_train_snv, num_steps)
    
    num_inputs_lstm = new_train_x.iloc[0]['snv'].shape[1]
    
    num_feature_not_snv = len(other_feature_selected)-1
    
    train_all, val_all, test_all = train_val_test(fc_dropout, num_feature_not_snv, num_fc_layers, batch_size, lr, patience,
                                                  num_outer_split, frac_inner_val, new_train_x, num_epochs, device, head, trsf_num_layer, 
                                                  trsf_dropout, trsf_hidden)
        
    train_all = np.array(train_all)
    val_all = np.array(val_all)
    test_all = np.array(test_all)
    train_loss, train_acc, train_auc, train_speed = train_all[:,0], train_all[:,1], train_all[:,2], train_all[:,3]
    val_loss, val_acc, val_auc = val_all[:,0], val_all[:,1], val_all[:,2]
    test_loss, test_acc, test_auc = test_all[:,0], test_all[:,1], test_all[:,2]    
    print('-'*20)
    print('One layer without smote without mask with early stopping under k-fold cv best model:')
    print('-'*20)
    print(f'On training set: Loss {train_loss.mean():.3f}, Accuracy {train_acc.mean():.3f}, Auc {train_auc.mean():.3f}, {train_speed.mean():.1f} samples/s {str(device)}.')
    print(f'On validation set: Loss {val_loss.mean():.3f}, Accuracy {val_acc.mean():.3f}, Auc {val_auc.mean():.3f}.')
    print(f'On test set: Loss {test_loss.mean():.3f}, Accuracy {test_acc.mean():.3f}, Auc {test_auc.mean():.3f}.')
    
    train_score = -train_auc.mean()
    val_score = -val_auc.mean()
    test_score = -test_auc.mean()
    
    tmp = val_score+test_score
    
    if tmp < best_score:
        best_score = tmp
        best_score = val_score
        print('*'*20)
        print("""Best parameters:
        snv_selected = %s
        other_feature_selected = %s
        fc_dropout = %f
        lr = %f
        patience = %d
        num_fc_layers = %d
        head = %d
        trsf_num_layer = %d
        trsf_dropout = %f
        trsf_hidden = %d
        """ % (snv_selected, other_feature_selected, fc_dropout, lr, patience, num_fc_layers, 
                                 head, trsf_num_layer, trsf_dropout, trsf_hidden))
        print('*'*20)
    else:
        print("""Current parameters:
        snv_selected = %s
        other_feature_selected = %s
        fc_dropout = %f
        lr = %f
        patience = %d
        num_fc_layers = %d
        head = %d
        trsf_num_layer = %d
        trsf_dropout = %f
        trsf_hidden = %d""" % (snv_selected, other_feature_selected, fc_dropout, lr, patience, num_fc_layers, 
                                 head, trsf_num_layer, trsf_dropout, trsf_hidden))
        
    frac_feature = 0.05*(len(other_feature_selected) - 1)/ len(other_feature_to_select)+ 0.01*len(snv_selected)/len(snv_to_select)

        
    return (0.5*tmp + frac_feature)

# %%
t = time.localtime()
print(str(t.tm_hour)+':'+str(t.tm_min))
# Out:
# 16:19

# %%
masked_gp = gp_minimize(masked_objective, search_spaces, n_calls=100, random_state=920,acq_func="EI",verbose=True, n_jobs=-1)

"Best score=%.4f" % masked_gp.fun

#---   Decoding feature selection results   ---#
bin_selected_features = bin(masked_gp.x[0])[2:]
for i in range(10-len(bin_selected_features)):
    bin_selected_features = '0' + bin_selected_features

tmp_bin_selected_features = bin(masked_gp.x[1])[2:]
for i in range(10-len(tmp_bin_selected_features)):
    tmp_bin_selected_features = '0' + tmp_bin_selected_features
bin_selected_features = bin_selected_features+ tmp_bin_selected_features

tmp_bin_selected_features = bin(masked_gp.x[2])[2:]
for i in range(10-len(tmp_bin_selected_features)):
    tmp_bin_selected_features = '0' + tmp_bin_selected_features
bin_selected_features = bin_selected_features+ tmp_bin_selected_features

tmp_bin_selected_features = bin(masked_gp.x[3])[2:]
for i in range(7-len(tmp_bin_selected_features)):
    tmp_bin_selected_features = '0' + tmp_bin_selected_features
bin_selected_features = bin_selected_features+ tmp_bin_selected_features

snv_selected = [snv_to_select[i] for i in range(len(snv_to_select)) if bin_selected_features[i] == '1']

snv_selected.append('patientID')

bin_selected_features = bin(masked_gp.x[4])[2:]
for i in range(9-len(bin_selected_features)):
    bin_selected_features = '0' + bin_selected_features


other_feature_selected = [other_feature_to_select[i] for i in range(len(other_feature_to_select)) if bin_selected_features[i] == '1']
other_feature_selected.append('label')
##---   Print parameters   ---##
print("""Best parameters:
        snv_selected = %s
        other_feature_selected = %s
        fc_dropout = %f
        lr = %f
        patience = %d
        num_fc_layers = %d
        head = %d
        trsf_num_layer = %d
        trsf_dropout = %f
        trsf_hidden = %d""" % (snv_selected, other_feature_selected, masked_gp.x[5],masked_gp.x[6], masked_gp.x[7],
                    masked_gp.x[8], masked_gp.x[9], masked_gp.x[10], masked_gp.x[11], masked_gp.x[12]))

from skopt.plots import plot_convergence

fig = plt.figure()
ax1=plot_convergence(masked_gp)
t = time.localtime()
plt.savefig(str(t.tm_year)+'-'+str(t.tm_mon)+'-'+str(t.tm_mday)+'-'+str(t.tm_hour)+'-'+str(t.tm_min)+'AutoTransformer.png')
plt.savefig(str(t.tm_year)+'-'+str(t.tm_mon)+'-'+str(t.tm_mday)+'-'+str(t.tm_hour)+'-'+str(t.tm_min)+'AutoTransformer.eps')
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.698, Accuracy 0.483, Auc 0.451, 244.1 samples/s cuda.
# On validation set: Loss 0.689, Accuracy 0.550, Auc 0.655.
# On test set: Loss 0.683, Accuracy 0.588, Auc 0.662.
# ********************
# Best parameters:
#         snv_selected = ['Gene', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'normalized_depth', 'gnomad_maxAF', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'tumor_adjudicated', 'cosmic_total_count', 'intersect_unpadded_selector', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Sex', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.323345
#         lr = 0.003741
#         patience = 7
#         num_fc_layers = 7
#         head = 2
#         trsf_num_layer = 10
#         trsf_dropout = 0.249747
#         trsf_hidden = 5
#
# ********************
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 109.6257
# Function value obtained: -0.6243
# Current minimum: -0.6243
# Iteration No: 2 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.498, Auc 0.498, 445.9 samples/s cuda.
# On validation set: Loss 0.691, Accuracy 0.556, Auc 0.841.
# On test set: Loss 0.686, Accuracy 0.650, Auc 0.824.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'mean_bc_family_size', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'variant_norm_bc_fam_size', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'cosmic_total_count', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'snv_valid_len', 'label']
#         fc_dropout = 0.315898
#         lr = 0.006994
#         patience = 5
#         num_fc_layers = 6
#         head = 2
#         trsf_num_layer = 4
#         trsf_dropout = 0.268139
#         trsf_hidden = 5
#
# ********************
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 28.6143
# Function value obtained: -0.8159
# Current minimum: -0.8159
# Iteration No: 3 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.485, Auc 0.500, 675.6 samples/s cuda.
# On validation set: Loss 0.692, Accuracy 0.556, Auc 0.500.
# On test set: Loss 0.689, Accuracy 0.588, Auc 0.500.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Percent.mutant.allele', 'mean_bc_family_size', 'variant_norm_bc_fam_size', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Sex', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.343754
#         lr = 0.006270
#         patience = 6
#         num_fc_layers = 9
#         head = 4
#         trsf_num_layer = 2
#         trsf_dropout = 0.113644
#         trsf_hidden = 9
#
# ********************
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 51.6864
# Function value obtained: -0.4732
# Current minimum: -0.8159
# Iteration No: 4 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.692, Accuracy 0.524, Auc 0.519, 254.9 samples/s cuda.
# On validation set: Loss 0.692, Accuracy 0.500, Auc 0.562.
# On test set: Loss 0.689, Accuracy 0.537, Auc 0.643.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'Position', 'variant_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_var_phred_score', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'cfdnabg_Bayesian_pval', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Plasma volume used', 'label']
#         fc_dropout = 0.315658
#         lr = 0.001607
#         patience = 4
#         num_fc_layers = 4
#         head = 6
#         trsf_num_layer = 9
#         trsf_dropout = 0.493651
#         trsf_hidden = 8
#
# ********************
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 45.6785
# Function value obtained: -0.5855
# Current minimum: -0.8159
# Iteration No: 5 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.693, Accuracy 0.505, Auc 0.510, 297.6 samples/s cuda.
# On validation set: Loss 0.692, Accuracy 0.562, Auc 0.513.
# On test set: Loss 0.690, Accuracy 0.650, Auc 0.505.
# ********************
# Best parameters:
#         snv_selected = ['Position', 'Gene', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'size_selected_adjustment', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.185660
#         lr = 0.013027
#         patience = 2
#         num_fc_layers = 8
#         head = 6
#         trsf_num_layer = 7
#         trsf_dropout = 0.120807
#         trsf_hidden = 9
#
# ********************
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 68.9053
# Function value obtained: -0.4642
# Current minimum: -0.8159
# Iteration No: 6 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.700, Accuracy 0.500, Auc 0.497, 257.2 samples/s cuda.
# On validation set: Loss 0.697, Accuracy 0.463, Auc 0.543.
# On test set: Loss 0.700, Accuracy 0.412, Auc 0.537.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Percent.mutant.allele', 'variant_count_norm', 'duplex_reads', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'intersect_unpadded_selector', 'cosmic_lung_count', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         fc_dropout = 0.175354
#         lr = 0.095156
#         patience = 4
#         num_fc_layers = 4
#         head = 6
#         trsf_num_layer = 9
#         trsf_dropout = 0.177730
#         trsf_hidden = 8
#
# ********************
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 18.0676
# Function value obtained: -0.5027
# Current minimum: -0.8159
# Iteration No: 7 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.515, Auc 0.516, 552.7 samples/s cuda.
# On validation set: Loss 0.692, Accuracy 0.500, Auc 0.653.
# On test set: Loss 0.697, Accuracy 0.469, Auc 0.671.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'fraction_MapQmin30', 'normalized_depth', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'BaseConversion', 'patientID']
#         other_feature_selected = ['Age (years)', 'label']
#         fc_dropout = 0.295659
#         lr = 0.005001
#         patience = 3
#         num_fc_layers = 4
#         head = 10
#         trsf_num_layer = 3
#         trsf_dropout = 0.475766
#         trsf_hidden = 4
#
# ********************
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 10.2655
# Function value obtained: -0.6505
# Current minimum: -0.8159
# Iteration No: 8 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.500, Auc 0.496, 527.4 samples/s cuda.
# On validation set: Loss 0.697, Accuracy 0.456, Auc 0.480.
# On test set: Loss 0.698, Accuracy 0.412, Auc 0.458.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'Position', 'Percent.mutant.allele', 'variant_count_norm', 'pass_split_1yes', 'duplex_reads', 'mean_bc_family_size', 'mean_var_phred_score', 'fraction_MapQmin30', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'cfdnabg_Bayesian_pval', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.472313
#         lr = 0.050876
#         patience = 4
#         num_fc_layers = 8
#         head = 8
#         trsf_num_layer = 3
#         trsf_dropout = 0.219920
#         trsf_hidden = 4
#
# ********************
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 10.5587
# Function value obtained: -0.4361
# Current minimum: -0.8159
# Iteration No: 9 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.697, Accuracy 0.511, Auc 0.535, 371.4 samples/s cuda.
# On validation set: Loss 0.696, Accuracy 0.487, Auc 0.612.
# On test set: Loss 0.693, Accuracy 0.475, Auc 0.647.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_var_phred_score', 'variant_norm_bc_fam_size', 'normalized_depth', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Age (years)', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.260874
#         lr = 0.023346
#         patience = 6
#         num_fc_layers = 3
#         head = 10
#         trsf_num_layer = 7
#         trsf_dropout = 0.129003
#         trsf_hidden = 6
#
# ********************
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 18.3458
# Function value obtained: -0.5838
# Current minimum: -0.8159
# Iteration No: 10 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.557, Accuracy 0.752, Auc 0.836, 243.6 samples/s cuda.
# On validation set: Loss 0.590, Accuracy 0.725, Auc 0.784.
# On test set: Loss 0.522, Accuracy 0.787, Auc 0.850.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'cfdnabg_Bayesian_pval', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         fc_dropout = 0.368095
#         lr = 0.003845
#         patience = 8
#         num_fc_layers = 1
#         head = 6
#         trsf_num_layer = 10
#         trsf_dropout = 0.150460
#         trsf_hidden = 7
#
# ********************
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 95.5931
# Function value obtained: -0.7931
# Current minimum: -0.8159
# Iteration No: 11 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.706, Accuracy 0.477, Auc 0.539, 233.1 samples/s cuda.
# On validation set: Loss 0.707, Accuracy 0.481, Auc 0.748.
# On test set: Loss 0.712, Accuracy 0.463, Auc 0.769.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_var_phred_score', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'cosmic_total_count', 'has_matched_tumor', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Sex', 'Smoker', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         fc_dropout = 0.291864
#         lr = 0.042415
#         patience = 1
#         num_fc_layers = 3
#         head = 2
#         trsf_num_layer = 9
#         trsf_dropout = 0.210292
#         trsf_hidden = 8
#
# ********************
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 9.1181
# Function value obtained: -0.7237
# Current minimum: -0.8159
# Iteration No: 12 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.616, Accuracy 0.687, Auc 0.735, 247.2 samples/s cuda.
# On validation set: Loss 0.597, Accuracy 0.713, Auc 0.723.
# On test set: Loss 0.616, Accuracy 0.650, Auc 0.750.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'germline_depth_at_position', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         fc_dropout = 0.426446
#         lr = 0.001696
#         patience = 9
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 9
#         trsf_dropout = 0.245146
#         trsf_hidden = 4
#
# ********************
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 210.4145
# Function value obtained: -0.6965
# Current minimum: -0.8159
# Iteration No: 13 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.699, Accuracy 0.528, Auc 0.533, 414.7 samples/s cuda.
# On validation set: Loss 0.683, Accuracy 0.625, Auc 0.806.
# On test set: Loss 0.677, Accuracy 0.681, Auc 0.832.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'sum_log10_frag_size_enrich_score', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.145189
#         lr = 0.005546
#         patience = 3
#         num_fc_layers = 8
#         head = 2
#         trsf_num_layer = 4
#         trsf_dropout = 0.128995
#         trsf_hidden = 6
#
# ********************
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 19.2582
# Function value obtained: -0.8067
# Current minimum: -0.8159
# Iteration No: 14 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.506, Auc 0.530, 565.0 samples/s cuda.
# On validation set: Loss 0.696, Accuracy 0.450, Auc 0.816.
# On test set: Loss 0.702, Accuracy 0.400, Auc 0.855.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'normalized_depth', 'base_change_transition', 'pass_basic_QC_nonsynon_lungdriver', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'tumor_adjudicated', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.334610
#         lr = 0.001313
#         patience = 8
#         num_fc_layers = 7
#         head = 2
#         trsf_num_layer = 3
#         trsf_dropout = 0.444100
#         trsf_hidden = 3
#
# ********************
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 113.4348
# Function value obtained: -0.7959
# Current minimum: -0.8159
# Iteration No: 15 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.701, Accuracy 0.498, Auc 0.554, 301.8 samples/s cuda.
# On validation set: Loss 0.693, Accuracy 0.500, Auc 0.512.
# On test set: Loss 0.695, Accuracy 0.525, Auc 0.571.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'has_matched_tumor', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Smoker', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.105534
#         lr = 0.001109
#         patience = 10
#         num_fc_layers = 7
#         head = 6
#         trsf_num_layer = 7
#         trsf_dropout = 0.222592
#         trsf_hidden = 4
#
# ********************
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 152.7263
# Function value obtained: -0.5018
# Current minimum: -0.8159
# Iteration No: 16 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.608, Accuracy 0.680, Auc 0.730, 596.0 samples/s cuda.
# On validation set: Loss 0.619, Accuracy 0.656, Auc 0.694.
# On test set: Loss 0.629, Accuracy 0.681, Auc 0.708.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'duplex_reads', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'variant_norm_bc_fam_size', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Sex', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         fc_dropout = 0.261398
#         lr = 0.003979
#         patience = 6
#         num_fc_layers = 1
#         head = 6
#         trsf_num_layer = 3
#         trsf_dropout = 0.464872
#         trsf_hidden = 9
#
# ********************
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 41.1147
# Function value obtained: -0.6666
# Current minimum: -0.8159
# Iteration No: 17 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.528, Accuracy 0.765, Auc 0.846, 630.8 samples/s cuda.
# On validation set: Loss 0.553, Accuracy 0.756, Auc 0.820.
# On test set: Loss 0.533, Accuracy 0.781, Auc 0.821.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_norm_varpos', 'mean_var_phred_score', 'variant_norm_bc_fam_size', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'intersect_unpadded_selector', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         fc_dropout = 0.162402
#         lr = 0.002045
#         patience = 8
#         num_fc_layers = 1
#         head = 4
#         trsf_num_layer = 3
#         trsf_dropout = 0.110281
#         trsf_hidden = 6
#
# ********************
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 42.2071
# Function value obtained: -0.7809
# Current minimum: -0.8159
# Iteration No: 18 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.696, Accuracy 0.524, Auc 0.500, 723.8 samples/s cuda.
# On validation set: Loss 0.691, Accuracy 0.575, Auc 0.826.
# On test set: Loss 0.687, Accuracy 0.669, Auc 0.835.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'variant_count_norm', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'intersect_unpadded_selector', 'patientID']
#         other_feature_selected = ['Sex', 'Smoker', 'Plasma volume used', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.216053
#         lr = 0.003443
#         patience = 2
#         num_fc_layers = 6
#         head = 2
#         trsf_num_layer = 2
#         trsf_dropout = 0.137507
#         trsf_hidden = 3
#
# ********************
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 16.0188
# Function value obtained: -0.7959
# Current minimum: -0.8159
# Iteration No: 19 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.536, Accuracy 0.766, Auc 0.847, 468.8 samples/s cuda.
# On validation set: Loss 0.576, Accuracy 0.719, Auc 0.852.
# On test set: Loss 0.493, Accuracy 0.819, Auc 0.884.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         fc_dropout = 0.101074
#         lr = 0.001048
#         patience = 6
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 6
#         trsf_dropout = 0.137643
#         trsf_hidden = 3
#
# ********************
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 63.3644
# Function value obtained: -0.8497
# Current minimum: -0.8497
# Iteration No: 20 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.633, Accuracy 0.669, Auc 0.676, 262.4 samples/s cuda.
# On validation set: Loss 0.685, Accuracy 0.619, Auc 0.633.
# On test set: Loss 0.653, Accuracy 0.625, Auc 0.644.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'variant_norm_bc_fam_size', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['Age (years)', 'Sex', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.224001
#         lr = 0.002500
#         patience = 7
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 10
#         trsf_dropout = 0.321224
#         trsf_hidden = 6
#
# ********************
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 112.0781
# Function value obtained: -0.6091
# Current minimum: -0.8497
# Iteration No: 21 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.680, Accuracy 0.554, Auc 0.592, 1163.4 samples/s cuda.
# On validation set: Loss 0.665, Accuracy 0.625, Auc 0.683.
# On test set: Loss 0.656, Accuracy 0.619, Auc 0.691.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Age (years)', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         fc_dropout = 0.150804
#         lr = 0.001000
#         patience = 3
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 1
#         trsf_dropout = 0.161747
#         trsf_hidden = 1
#
# ********************
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 11.2516
# Function value obtained: -0.6536
# Current minimum: -0.8497
# Iteration No: 22 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.588, Accuracy 0.692, Auc 0.746, 342.0 samples/s cuda.
# On validation set: Loss 0.550, Accuracy 0.787, Auc 0.788.
# On test set: Loss 0.560, Accuracy 0.738, Auc 0.812.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Percent.mutant.allele', 'variant_count_norm', 'pass_split_1yes', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'intersect_unpadded_selector', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.128933
#         lr = 0.001000
#         patience = 10
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 9
#         trsf_dropout = 0.124189
#         trsf_hidden = 1
#
# ********************
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 169.3699
# Function value obtained: -0.7890
# Current minimum: -0.8497
# Iteration No: 23 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.611, Accuracy 0.670, Auc 0.725, 1268.6 samples/s cuda.
# On validation set: Loss 0.585, Accuracy 0.681, Auc 0.821.
# On test set: Loss 0.577, Accuracy 0.713, Auc 0.803.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'variant_count_norm', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'has_matched_tumor', 'intersect_unpadded_selector', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Sex', 'Smoker', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.134860
#         lr = 0.001163
#         patience = 2
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.119564
#         trsf_hidden = 6
#
# ********************
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 19.2586
# Function value obtained: -0.7776
# Current minimum: -0.8497
# Iteration No: 24 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.679, Accuracy 0.560, Auc 0.567, 329.4 samples/s cuda.
# On validation set: Loss 0.677, Accuracy 0.506, Auc 0.684.
# On test set: Loss 0.710, Accuracy 0.419, Auc 0.640.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'variant_count_norm', 'duplex_reads', 'watsoncrickfisher.p', 'mean_var_phred_score', 'variant_norm_bc_fam_size', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'intersect_unpadded_selector', 'patientID']
#         other_feature_selected = ['Age (years)', 'Sex', 'Plasma volume used', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.166036
#         lr = 0.003055
#         patience = 4
#         num_fc_layers = 1
#         head = 4
#         trsf_num_layer = 8
#         trsf_dropout = 0.161073
#         trsf_hidden = 6
#
# ********************
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 28.6676
# Function value obtained: -0.6338
# Current minimum: -0.8497
# Iteration No: 25 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.606, Accuracy 0.673, Auc 0.742, 528.1 samples/s cuda.
# On validation set: Loss 0.665, Accuracy 0.606, Auc 0.793.
# On test set: Loss 0.644, Accuracy 0.625, Auc 0.793.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'variant_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'normalized_depth', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'sum_log10_frag_size_enrich_score', 'tumor_adjudicated', 'cosmic_total_count', 'intersect_unpadded_selector', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['Sex', 'Smoker', 'Plasma volume used', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.102120
#         lr = 0.100000
#         patience = 8
#         num_fc_layers = 2
#         head = 2
#         trsf_num_layer = 4
#         trsf_dropout = 0.427567
#         trsf_hidden = 1
#
# ********************
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 33.9883
# Function value obtained: -0.7611
# Current minimum: -0.8497
# Iteration No: 26 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.661, Accuracy 0.635, Auc 0.663, 430.5 samples/s cuda.
# On validation set: Loss 0.657, Accuracy 0.606, Auc 0.673.
# On test set: Loss 0.618, Accuracy 0.694, Auc 0.724.
# ********************
# Best parameters:
#         snv_selected = ['Position', 'Gene', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Sex', 'Plasma volume used', 'snv_valid_len', 'label']
#         fc_dropout = 0.226705
#         lr = 0.002337
#         patience = 2
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 7
#         trsf_dropout = 0.343865
#         trsf_hidden = 6
#
# ********************
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 31.2706
# Function value obtained: -0.6693
# Current minimum: -0.8497
# Iteration No: 27 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.706, Accuracy 0.574, Auc 0.588, 415.8 samples/s cuda.
# On validation set: Loss 0.692, Accuracy 0.588, Auc 0.660.
# On test set: Loss 0.645, Accuracy 0.613, Auc 0.679.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Gene', 'Percent.mutant.allele', 'pass_split_1yes', 'duplex_reads', 'mean_bc_family_size', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'cosmic_total_count', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.207513
#         lr = 0.001699
#         patience = 3
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 7
#         trsf_dropout = 0.208635
#         trsf_hidden = 8
#
# ********************
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 20.7140
# Function value obtained: -0.6357
# Current minimum: -0.8497
# Iteration No: 28 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.698, Accuracy 0.506, Auc 0.475, 560.7 samples/s cuda.
# On validation set: Loss 0.690, Accuracy 0.550, Auc 0.665.
# On test set: Loss 0.686, Accuracy 0.588, Auc 0.752.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'variant_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_var_phred_score', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         fc_dropout = 0.147640
#         lr = 0.010426
#         patience = 2
#         num_fc_layers = 5
#         head = 2
#         trsf_num_layer = 4
#         trsf_dropout = 0.125975
#         trsf_hidden = 9
#
# ********************
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 6.7935
# Function value obtained: -0.6696
# Current minimum: -0.8497
# Iteration No: 29 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.813, Accuracy 0.500, Auc 0.500, 363.6 samples/s cuda.
# On validation set: Loss 0.757, Accuracy 0.556, Auc 0.500.
# On test set: Loss 0.788, Accuracy 0.525, Auc 0.500.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'Gene', 'Percent.mutant.allele', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.196218
#         lr = 0.094980
#         patience = 7
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 7
#         trsf_dropout = 0.325670
#         trsf_hidden = 2
#
# ********************
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 138.7979
# Function value obtained: -0.4882
# Current minimum: -0.8497
# Iteration No: 30 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.606, Accuracy 0.670, Auc 0.691, 349.2 samples/s cuda.
# On validation set: Loss 0.687, Accuracy 0.544, Auc 0.542.
# On test set: Loss 0.674, Accuracy 0.588, Auc 0.606.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_depth_at_position', 'cosmic_total_count', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.101210
#         lr = 0.001000
#         patience = 9
#         num_fc_layers = 1
#         head = 8
#         trsf_num_layer = 6
#         trsf_dropout = 0.140906
#         trsf_hidden = 3
#
# ********************
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 69.3960
# Function value obtained: -0.5625
# Current minimum: -0.8497
# Iteration No: 31 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.647, Accuracy 0.654, Auc 0.683, 347.4 samples/s cuda.
# On validation set: Loss 0.657, Accuracy 0.625, Auc 0.756.
# On test set: Loss 0.643, Accuracy 0.606, Auc 0.747.
# ********************
# Best parameters:
#         snv_selected = ['germline_NumNonZeroMeanAF_Pval', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'gnomad_maxAF', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cosmic_total_count', 'intersect_unpadded_selector', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.185029
#         lr = 0.001000
#         patience = 9
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 6
#         trsf_dropout = 0.319132
#         trsf_hidden = 5
#
# ********************
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 92.2884
# Function value obtained: -0.7094
# Current minimum: -0.8497
# Iteration No: 32 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.508, Auc 0.527, 215.1 samples/s cuda.
# On validation set: Loss 0.693, Accuracy 0.531, Auc 0.500.
# On test set: Loss 0.688, Accuracy 0.600, Auc 0.500.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'gnomad_maxAF', 'cfdnabg_Bayesian_pval', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['Smoker', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.103770
#         lr = 0.100000
#         patience = 2
#         num_fc_layers = 10
#         head = 2
#         trsf_num_layer = 10
#         trsf_dropout = 0.101325
#         trsf_hidden = 2
#
# ********************
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 19.0165
# Function value obtained: -0.4840
# Current minimum: -0.8497
# Iteration No: 33 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.670, Accuracy 0.573, Auc 0.624, 991.8 samples/s cuda.
# On validation set: Loss 0.661, Accuracy 0.619, Auc 0.852.
# On test set: Loss 0.655, Accuracy 0.700, Auc 0.857.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'fraction_MapQmin30', 'gnomad_maxAF', 'base_change_transition', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         fc_dropout = 0.338203
#         lr = 0.001000
#         patience = 6
#         num_fc_layers = 4
#         head = 2
# ...
#         trsf_num_layer = 7
#         trsf_dropout = 0.209816
#         trsf_hidden = 2
#
# ********************
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 202.9725
# Function value obtained: -0.8670
# Current minimum: -0.8670
# Iteration No: 90 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.717, Accuracy 0.511, Auc 0.511, 103.7 samples/s cuda.
# On validation set: Loss 0.684, Accuracy 0.556, Auc 0.625.
# On test set: Loss 0.681, Accuracy 0.581, Auc 0.577.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'normalized_depth', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Sex', 'Plasma volume used', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.100000
#         lr = 0.004291
#         patience = 1
#         num_fc_layers = 1
#         head = 4
#         trsf_num_layer = 7
#         trsf_dropout = 0.259404
#         trsf_hidden = 2
#
# ********************
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 27.8188
# Function value obtained: -0.5725
# Current minimum: -0.8670
# Iteration No: 91 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.682, Accuracy 0.588, Auc 0.578, 108.1 samples/s cuda.
# On validation set: Loss 0.670, Accuracy 0.644, Auc 0.498.
# On test set: Loss 0.656, Accuracy 0.706, Auc 0.504.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'normalized_depth', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['Plasma volume used', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.107426
#         lr = 0.001978
#         patience = 6
#         num_fc_layers = 6
#         head = 8
#         trsf_num_layer = 8
#         trsf_dropout = 0.434043
#         trsf_hidden = 3
#
# ********************
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 289.3781
# Function value obtained: -0.4831
# Current minimum: -0.8670
# Iteration No: 92 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.696, Accuracy 0.488, Auc 0.484, 306.2 samples/s cuda.
# On validation set: Loss 0.698, Accuracy 0.494, Auc 0.564.
# On test set: Loss 0.714, Accuracy 0.419, Auc 0.607.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'base_change_transition', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Plasma DNA input (ng)', 'label']
#         fc_dropout = 0.406569
#         lr = 0.001027
#         patience = 8
#         num_fc_layers = 3
#         head = 4
#         trsf_num_layer = 2
#         trsf_dropout = 0.490517
#         trsf_hidden = 2
#
# ********************
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 42.2069
# Function value obtained: -0.5622
# Current minimum: -0.8670
# Iteration No: 93 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.570, Accuracy 0.736, Auc 0.739, 494.0 samples/s cuda.
# On validation set: Loss 0.625, Accuracy 0.669, Auc 0.738.
# On test set: Loss 0.612, Accuracy 0.700, Auc 0.779.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Gene', 'ontarget_shoulder_tile_mut_count_norm', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.351577
#         lr = 0.002970
#         patience = 7
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.238119
#         trsf_hidden = 5
#
# ********************
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 39.6490
# Function value obtained: -0.7485
# Current minimum: -0.8670
# Iteration No: 94 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.702, Accuracy 0.504, Auc 0.492, 335.0 samples/s cuda.
# On validation set: Loss 0.689, Accuracy 0.537, Auc 0.726.
# On test set: Loss 0.688, Accuracy 0.525, Auc 0.742.
# ********************
# Best parameters:
#         snv_selected = ['Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.279135
#         lr = 0.001000
#         patience = 1
#         num_fc_layers = 8
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.146935
#         trsf_hidden = 9
#
# ********************
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 82.9032
# Function value obtained: -0.7230
# Current minimum: -0.8670
# Iteration No: 95 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.507, Accuracy 0.798, Auc 0.866, 718.5 samples/s cuda.
# On validation set: Loss 0.604, Accuracy 0.681, Auc 0.812.
# On test set: Loss 0.505, Accuracy 0.812, Auc 0.848.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'Percent.mutant.allele', 'variant_count_norm', 'duplex_reads', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.149250
#         lr = 0.003911
#         patience = 10
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.302294
#         trsf_hidden = 7
#
# ********************
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 70.2414
# Function value obtained: -0.8189
# Current minimum: -0.8670
# Iteration No: 96 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.513, Accuracy 0.806, Auc 0.873, 518.4 samples/s cuda.
# On validation set: Loss 0.579, Accuracy 0.725, Auc 0.802.
# On test set: Loss 0.506, Accuracy 0.794, Auc 0.879.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'Percent.mutant.allele', 'duplex_reads', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.104203
#         lr = 0.003740
#         patience = 10
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.303012
#         trsf_hidden = 5
#
# ********************
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 58.8241
# Function value obtained: -0.8294
# Current minimum: -0.8670
# Iteration No: 97 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.650, Accuracy 0.591, Auc 0.603, 470.0 samples/s cuda.
# On validation set: Loss 0.637, Accuracy 0.562, Auc 0.872.
# On test set: Loss 0.669, Accuracy 0.494, Auc 0.852.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'Percent.mutant.allele', 'pass_split_1yes', 'mean_norm_varpos', 'variant_norm_bc_fam_size', 'normalized_depth', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.496940
#         lr = 0.002555
#         patience = 6
#         num_fc_layers = 3
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.244110
#         trsf_hidden = 7
#
# ********************
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 39.3699
# Function value obtained: -0.8520
# Current minimum: -0.8670
# Iteration No: 98 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.464, Accuracy 0.860, Auc 0.911, 440.7 samples/s cuda.
# On validation set: Loss 0.540, Accuracy 0.769, Auc 0.866.
# On test set: Loss 0.477, Accuracy 0.838, Auc 0.913.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.120770
#         lr = 0.002464
#         patience = 7
#         num_fc_layers = 2
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.241060
#         trsf_hidden = 10
#
# ********************
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 50.7564
# Function value obtained: -0.8772
# Current minimum: -0.8772
# Iteration No: 99 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.698, Accuracy 0.496, Auc 0.496, 214.2 samples/s cuda.
# On validation set: Loss 0.691, Accuracy 0.481, Auc 0.857.
# On test set: Loss 0.697, Accuracy 0.475, Auc 0.848.
# ********************
# Best parameters:
#         snv_selected = ['Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'sum_log10_frag_size_enrich_score', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.261918
#         lr = 0.001424
#         patience = 5
#         num_fc_layers = 8
#         head = 2
#         trsf_num_layer = 3
#         trsf_dropout = 0.336462
#         trsf_hidden = 5
#
# ********************
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 209.6408
# Function value obtained: -0.8427
# Current minimum: -0.8772
# Iteration No: 100 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.683, Accuracy 0.554, Auc 0.596, 167.3 samples/s cuda.
# On validation set: Loss 0.674, Accuracy 0.600, Auc 0.627.
# On test set: Loss 0.656, Accuracy 0.644, Auc 0.677.
# ********************
# Best parameters:
#         snv_selected = ['Position', 'Gene', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'fraction_MapQmin30', 'base_change_transition', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'intersect_unpadded_selector', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Plasma volume used', 'label']
#         fc_dropout = 0.139628
#         lr = 0.001408
#         patience = 6
#         num_fc_layers = 5
#         head = 4
#         trsf_num_layer = 5
#         trsf_dropout = 0.101722
#         trsf_hidden = 1
#
# ********************
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 144.8303
# Function value obtained: -0.6360
# Current minimum: -0.8772
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         fc_dropout = 0.120770
#         lr = 0.002464
#         patience = 7
#         num_fc_layers = 2
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.241060
#         trsf_hidden = 10

# %%
# ---------------------------------------------------#   
#    Parameter Tuning with Bayesian optimization    #
#--------------------------------------------------# 
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

seed = 1105

num_outer_split = 5

num_output_nodes, num_epochs = 2, 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

fc_dropout, lr, patience, num_fc_layers = masked_gp.x[5],masked_gp.x[6], masked_gp.x[7], masked_gp.x[8]
head, trsf_num_layer, trsf_dropout, trsf_hidden = masked_gp.x[9], masked_gp.x[10], masked_gp.x[11], masked_gp.x[12]

new_train_snv = deepcopy(train_snv[snv_selected])
new_train_x = deepcopy(train_x[other_feature_selected])
new_train_x = NewGroupAndExtractSNV(new_train_x, new_train_snv, num_steps)

new_test_snv = deepcopy(test_snv[snv_selected])
new_test_x = deepcopy(test_x[other_feature_selected])
new_test_x = NewGroupAndExtractSNV(new_test_x, new_test_snv, num_steps)

num_inputs_lstm = new_train_x.iloc[0]['snv'].shape[1]
num_feature_not_snv = len(other_feature_selected)-1

num_repeat = 100
frac_val = 0.25
train_all = []
val_all = []
test_all = []
for i in range(num_repeat):
    
    seed = seed + i
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
    sub_train_index, sub_val_index = next(StratifiedShuffleSplit(n_splits=1,test_size=frac_val).split(new_train_x,new_train_x['label']))

    #---  Seperate traing set, validation set and test set ---#
    sub_train = Resampler(new_train_x.iloc[sub_train_index][:], new_train_x.iloc[sub_train_index]['label'])
    train_iter = BatchDataGeneration(sub_train, batch_size, shuffle=True)
    val_iter = BatchDataGeneration(new_train_x.iloc[sub_val_index][:], batch_size, shuffle=True)
    test_iter = BatchDataGeneration(new_test_x, batch_size, shuffle=True)
    
    shape = new_train_x['snv'][0].shape
    
    #-----  Instantiate model -----#
    
    model = AutoTransformer(fc_dropout, num_feature_not_snv, num_output_nodes, num_fc_layers, device, 
                                     head, trsf_num_layer, trsf_dropout, trsf_hidden, shape)
    model = model.to(device)
    model.apply(init_weights)
    
    #-----  Loss -----#
    loss = nn.CrossEntropyLoss(reduction="none")
    loss = loss.to(device)

    #--- Define optimizer ---#
    optimizer = torch.optim.Adam(model.parameters(), lr)

    #-----  Instantiate EarlyStopping -----#
    early_stopping = EarlyStopping(patience, verbose=False)

    train_loss, train_acc, train_auc, train_speed, val_loss, val_acc, val_auc = train_evaluate(
        model, train_iter, val_iter, loss, optimizer, early_stopping, num_epochs, device)

    test_loss, test_acc, test_auc = evaluate(model, test_iter, loss, device)

    train_all.append([train_loss, train_acc, train_auc, train_speed])
    val_all.append([val_loss, val_acc, val_auc])
    test_all.append([test_loss, test_acc, test_auc])
    print('-'*20)
    print('num of repeat:', i)
    print('-'*20)
    print(f'On training set: Loss {train_loss:.3f}, Accuracy {train_acc:.3f}, Auc {train_auc:.3f}, {train_speed:.1f} samples/s {str(device)}.')
    print(f'On validation set: Loss {val_loss:.3f}, Accuracy {val_acc:.3f}, Auc {val_auc:.3f}.')
    print(f'On test set: Loss {test_loss:.3f}, Accuracy {test_acc:.3f}, Auc {test_auc:.3f}.')


train_all = np.array(train_all)
val_all = np.array(val_all)
test_all = np.array(test_all)

train_loss, train_acc, train_auc, train_speed = train_all[:,0], train_all[:,1], train_all[:,2], train_all[:,3]
val_loss, val_acc, val_auc = val_all[:,0], val_all[:,1], val_all[:,2]
test_loss, test_acc, test_auc = test_all[:,0], test_all[:,1], test_all[:,2]    
print('-'*20)
print('One layer without smote with mask with early stopping under k-fold cv best model:')
print('-'*20)
print(f'On training set: Loss {train_loss.mean():.3f}, Accuracy {train_acc.mean():.3f}, Auc {train_auc.mean():.3f}, {train_speed.mean():.1f} samples/s {str(device)}.')
print(f'On validation set: Loss {val_loss.mean():.3f}, Accuracy {val_acc.mean():.3f}, Auc {val_auc.mean():.3f}.')
print(f'On test set: Loss {test_loss.mean():.3f}, Accuracy {test_acc.mean():.3f}, Auc {test_auc.mean():.3f}.')

#-----  Save performance -----#
df = (('train_loss', 'train_acc', 'train_auc', 'train_speed', 'val_loss', 'val_acc', 'val_auc', 'test_loss', 'test_acc', 'test_auc'),  
      (train_loss, train_acc, train_auc, train_speed, val_loss, val_acc, val_auc, test_loss, test_acc, test_auc)  
      )
df = pd.DataFrame(df)
t = time.localtime()
file_name = 'AutoTransformer'+str(t.tm_year)+'-'+str(t.tm_mon)+'-'+str(t.tm_mday)+'-'+str(t.tm_hour)+'-'+str(t.tm_min)+'.xlsx' #(t.tm_year)
df.to_excel(file_name,index = False)
# Out:
# --------------------
# num of repeat: 0
# --------------------
# On training set: Loss 0.362, Accuracy 0.955, Auc 0.968, 402.1 samples/s cuda.
# On validation set: Loss 0.513, Accuracy 0.800, Auc 0.886.
# On test set: Loss 0.570, Accuracy 0.734, Auc 0.798.
# --------------------
# num of repeat: 1
# --------------------
# On training set: Loss 0.357, Accuracy 0.955, Auc 0.972, 437.0 samples/s cuda.
# On validation set: Loss 0.470, Accuracy 0.850, Auc 0.838.
# On test set: Loss 0.589, Accuracy 0.723, Auc 0.748.
# --------------------
# num of repeat: 2
# --------------------
# On training set: Loss 0.365, Accuracy 0.962, Auc 0.939, 413.8 samples/s cuda.
# On validation set: Loss 0.538, Accuracy 0.775, Auc 0.819.
# On test set: Loss 0.555, Accuracy 0.755, Auc 0.770.
# --------------------
# num of repeat: 3
# --------------------
# On training set: Loss 0.397, Accuracy 0.923, Auc 0.934, 406.3 samples/s cuda.
# On validation set: Loss 0.491, Accuracy 0.825, Auc 0.920.
# On test set: Loss 0.582, Accuracy 0.713, Auc 0.705.
# --------------------
# num of repeat: 4
# --------------------
# On training set: Loss 0.489, Accuracy 0.814, Auc 0.888, 418.3 samples/s cuda.
# On validation set: Loss 0.546, Accuracy 0.750, Auc 0.848.
# On test set: Loss 0.625, Accuracy 0.681, Auc 0.744.
# --------------------
# num of repeat: 5
# --------------------
# On training set: Loss 0.358, Accuracy 0.968, Auc 0.961, 426.2 samples/s cuda.
# On validation set: Loss 0.555, Accuracy 0.725, Auc 0.838.
# On test set: Loss 0.597, Accuracy 0.723, Auc 0.717.
# --------------------
# num of repeat: 6
# --------------------
# On training set: Loss 0.505, Accuracy 0.795, Auc 0.878, 421.6 samples/s cuda.
# On validation set: Loss 0.557, Accuracy 0.750, Auc 0.816.
# On test set: Loss 0.637, Accuracy 0.670, Auc 0.706.
# --------------------
# num of repeat: 7
# --------------------
# On training set: Loss 0.359, Accuracy 0.955, Auc 0.972, 443.1 samples/s cuda.
# On validation set: Loss 0.480, Accuracy 0.825, Auc 0.863.
# On test set: Loss 0.628, Accuracy 0.691, Auc 0.762.
# --------------------
# num of repeat: 8
# --------------------
# On training set: Loss 0.416, Accuracy 0.897, Auc 0.931, 446.9 samples/s cuda.
# On validation set: Loss 0.456, Accuracy 0.850, Auc 0.935.
# On test set: Loss 0.579, Accuracy 0.723, Auc 0.757.
# --------------------
# num of repeat: 9
# --------------------
# On training set: Loss 0.504, Accuracy 0.833, Auc 0.868, 467.0 samples/s cuda.
# On validation set: Loss 0.560, Accuracy 0.725, Auc 0.820.
# On test set: Loss 0.623, Accuracy 0.681, Auc 0.732.
# --------------------
# num of repeat: 10
# --------------------
# On training set: Loss 0.417, Accuracy 0.904, Auc 0.936, 485.8 samples/s cuda.
# On validation set: Loss 0.479, Accuracy 0.825, Auc 0.926.
# On test set: Loss 0.602, Accuracy 0.702, Auc 0.746.
# --------------------
# num of repeat: 11
# --------------------
# On training set: Loss 0.506, Accuracy 0.821, Auc 0.875, 427.4 samples/s cuda.
# On validation set: Loss 0.556, Accuracy 0.750, Auc 0.843.
# On test set: Loss 0.627, Accuracy 0.649, Auc 0.727.
# --------------------
# num of repeat: 12
# --------------------
# On training set: Loss 0.370, Accuracy 0.955, Auc 0.968, 403.2 samples/s cuda.
# On validation set: Loss 0.503, Accuracy 0.800, Auc 0.898.
# On test set: Loss 0.534, Accuracy 0.787, Auc 0.809.
# --------------------
# num of repeat: 13
# --------------------
# On training set: Loss 0.397, Accuracy 0.910, Auc 0.967, 413.8 samples/s cuda.
# On validation set: Loss 0.671, Accuracy 0.625, Auc 0.698.
# On test set: Loss 0.581, Accuracy 0.723, Auc 0.765.
# --------------------
# num of repeat: 14
# --------------------
# On training set: Loss 0.388, Accuracy 0.923, Auc 0.966, 425.1 samples/s cuda.
# On validation set: Loss 0.462, Accuracy 0.850, Auc 0.819.
# On test set: Loss 0.652, Accuracy 0.660, Auc 0.720.
# --------------------
# num of repeat: 15
# --------------------
# On training set: Loss 0.440, Accuracy 0.891, Auc 0.908, 390.1 samples/s cuda.
# On validation set: Loss 0.514, Accuracy 0.800, Auc 0.865.
# On test set: Loss 0.638, Accuracy 0.660, Auc 0.739.
# --------------------
# num of repeat: 16
# --------------------
# On training set: Loss 0.403, Accuracy 0.910, Auc 0.953, 416.0 samples/s cuda.
# On validation set: Loss 0.509, Accuracy 0.800, Auc 0.868.
# On test set: Loss 0.594, Accuracy 0.702, Auc 0.779.
# --------------------
# num of repeat: 17
# --------------------
# On training set: Loss 0.428, Accuracy 0.891, Auc 0.929, 408.4 samples/s cuda.
# On validation set: Loss 0.455, Accuracy 0.850, Auc 0.893.
# On test set: Loss 0.619, Accuracy 0.691, Auc 0.733.
# --------------------
# num of repeat: 18
# --------------------
# On training set: Loss 0.353, Accuracy 0.962, Auc 0.984, 441.9 samples/s cuda.
# On validation set: Loss 0.636, Accuracy 0.650, Auc 0.805.
# On test set: Loss 0.622, Accuracy 0.681, Auc 0.726.
# --------------------
# num of repeat: 19
# --------------------
# On training set: Loss 0.363, Accuracy 0.955, Auc 0.965, 577.2 samples/s cuda.
# On validation set: Loss 0.564, Accuracy 0.750, Auc 0.799.
# On test set: Loss 0.579, Accuracy 0.734, Auc 0.725.
# --------------------
# num of repeat: 20
# --------------------
# On training set: Loss 0.418, Accuracy 0.904, Auc 0.934, 404.2 samples/s cuda.
# On validation set: Loss 0.533, Accuracy 0.800, Auc 0.891.
# On test set: Loss 0.629, Accuracy 0.681, Auc 0.770.
# --------------------
# num of repeat: 21
# --------------------
# On training set: Loss 0.408, Accuracy 0.917, Auc 0.920, 444.4 samples/s cuda.
# On validation set: Loss 0.463, Accuracy 0.850, Auc 0.931.
# On test set: Loss 0.588, Accuracy 0.713, Auc 0.709.
# --------------------
# num of repeat: 22
# --------------------
# On training set: Loss 0.411, Accuracy 0.910, Auc 0.914, 467.0 samples/s cuda.
# On validation set: Loss 0.548, Accuracy 0.775, Auc 0.838.
# On test set: Loss 0.676, Accuracy 0.628, Auc 0.714.
# --------------------
# num of repeat: 23
# --------------------
# On training set: Loss 0.405, Accuracy 0.923, Auc 0.942, 460.1 samples/s cuda.
# On validation set: Loss 0.519, Accuracy 0.775, Auc 0.893.
# On test set: Loss 0.572, Accuracy 0.734, Auc 0.785.
# --------------------
# num of repeat: 24
# --------------------
# On training set: Loss 0.479, Accuracy 0.853, Auc 0.905, 434.5 samples/s cuda.
# On validation set: Loss 0.612, Accuracy 0.675, Auc 0.816.
# On test set: Loss 0.626, Accuracy 0.670, Auc 0.743.
# --------------------
# num of repeat: 25
# --------------------
# On training set: Loss 0.437, Accuracy 0.878, Auc 0.939, 491.9 samples/s cuda.
# On validation set: Loss 0.538, Accuracy 0.750, Auc 0.820.
# On test set: Loss 0.588, Accuracy 0.723, Auc 0.762.
# --------------------
# num of repeat: 26
# --------------------
# On training set: Loss 0.390, Accuracy 0.929, Auc 0.964, 418.3 samples/s cuda.
# On validation set: Loss 0.631, Accuracy 0.675, Auc 0.758.
# On test set: Loss 0.576, Accuracy 0.734, Auc 0.786.
# --------------------
# num of repeat: 27
# --------------------
# On training set: Loss 0.375, Accuracy 0.936, Auc 0.964, 441.9 samples/s cuda.
# On validation set: Loss 0.588, Accuracy 0.725, Auc 0.783.
# On test set: Loss 0.603, Accuracy 0.702, Auc 0.771.
# --------------------
# num of repeat: 28
# --------------------
# On training set: Loss 0.438, Accuracy 0.891, Auc 0.953, 620.8 samples/s cuda.
# On validation set: Loss 0.615, Accuracy 0.650, Auc 0.783.
# On test set: Loss 0.604, Accuracy 0.702, Auc 0.738.
# --------------------
# num of repeat: 29
# --------------------
# On training set: Loss 0.397, Accuracy 0.923, Auc 0.951, 421.6 samples/s cuda.
# On validation set: Loss 0.525, Accuracy 0.775, Auc 0.809.
# On test set: Loss 0.609, Accuracy 0.702, Auc 0.786.
# --------------------
# num of repeat: 30
# --------------------
# On training set: Loss 0.376, Accuracy 0.949, Auc 0.966, 488.8 samples/s cuda.
# On validation set: Loss 0.653, Accuracy 0.650, Auc 0.765.
# On test set: Loss 0.604, Accuracy 0.702, Auc 0.744.
# --------------------
# num of repeat: 31
# --------------------
# On training set: Loss 0.335, Accuracy 0.981, Auc 0.977, 434.5 samples/s cuda.
# On validation set: Loss 0.562, Accuracy 0.750, Auc 0.805.
# On test set: Loss 0.595, Accuracy 0.713, Auc 0.776.
# --------------------
# num of repeat: 32
# --------------------
# On training set: Loss 0.411, Accuracy 0.910, Auc 0.920, 560.7 samples/s cuda.
# On validation set: Loss 0.607, Accuracy 0.700, Auc 0.703.
# On test set: Loss 0.574, Accuracy 0.745, Auc 0.698.
# --------------------
# num of repeat: 33
# --------------------
# On training set: Loss 0.366, Accuracy 0.962, Auc 0.960, 468.4 samples/s cuda.
# On validation set: Loss 0.538, Accuracy 0.750, Auc 0.865.
# On test set: Loss 0.574, Accuracy 0.734, Auc 0.767.
# --------------------
# num of repeat: 34
# --------------------
# On training set: Loss 0.512, Accuracy 0.808, Auc 0.887, 413.8 samples/s cuda.
# On validation set: Loss 0.620, Accuracy 0.650, Auc 0.786.
# On test set: Loss 0.618, Accuracy 0.670, Auc 0.736.
# --------------------
# num of repeat: 35
# --------------------
# On training set: Loss 0.563, Accuracy 0.744, Auc 0.815, 429.8 samples/s cuda.
# On validation set: Loss 0.674, Accuracy 0.550, Auc 0.813.
# On test set: Loss 0.646, Accuracy 0.628, Auc 0.718.
# --------------------
# num of repeat: 36
# --------------------
# On training set: Loss 0.480, Accuracy 0.833, Auc 0.914, 414.9 samples/s cuda.
# On validation set: Loss 0.610, Accuracy 0.650, Auc 0.783.
# On test set: Loss 0.617, Accuracy 0.681, Auc 0.735.
# --------------------
# num of repeat: 37
# --------------------
# On training set: Loss 0.440, Accuracy 0.865, Auc 0.930, 526.7 samples/s cuda.
# On validation set: Loss 0.458, Accuracy 0.850, Auc 0.931.
# On test set: Loss 0.568, Accuracy 0.755, Auc 0.773.
# --------------------
# num of repeat: 38
# --------------------
# On training set: Loss 0.443, Accuracy 0.878, Auc 0.942, 426.2 samples/s cuda.
# On validation set: Loss 0.605, Accuracy 0.700, Auc 0.673.
# On test set: Loss 0.602, Accuracy 0.702, Auc 0.734.
# --------------------
# num of repeat: 39
# --------------------
# On training set: Loss 0.420, Accuracy 0.891, Auc 0.933, 456.1 samples/s cuda.
# On validation set: Loss 0.531, Accuracy 0.800, Auc 0.871.
# On test set: Loss 0.627, Accuracy 0.670, Auc 0.711.
# --------------------
# num of repeat: 40
# --------------------
# On training set: Loss 0.420, Accuracy 0.910, Auc 0.929, 434.5 samples/s cuda.
# On validation set: Loss 0.556, Accuracy 0.725, Auc 0.819.
# On test set: Loss 0.610, Accuracy 0.681, Auc 0.725.
# --------------------
# num of repeat: 41
# --------------------
# On training set: Loss 0.510, Accuracy 0.821, Auc 0.868, 537.6 samples/s cuda.
# On validation set: Loss 0.586, Accuracy 0.700, Auc 0.832.
# On test set: Loss 0.647, Accuracy 0.638, Auc 0.708.
# --------------------
# num of repeat: 42
# --------------------
# On training set: Loss 0.398, Accuracy 0.917, Auc 0.966, 430.9 samples/s cuda.
# On validation set: Loss 0.513, Accuracy 0.800, Auc 0.691.
# On test set: Loss 0.578, Accuracy 0.734, Auc 0.755.
# --------------------
# num of repeat: 43
# --------------------
# On training set: Loss 0.384, Accuracy 0.929, Auc 0.940, 539.4 samples/s cuda.
# On validation set: Loss 0.400, Accuracy 0.900, Auc 0.981.
# On test set: Loss 0.603, Accuracy 0.713, Auc 0.785.
# --------------------
# num of repeat: 44
# --------------------
# On training set: Loss 0.406, Accuracy 0.910, Auc 0.923, 397.0 samples/s cuda.
# On validation set: Loss 0.536, Accuracy 0.775, Auc 0.791.
# On test set: Loss 0.592, Accuracy 0.723, Auc 0.772.
# --------------------
# num of repeat: 45
# --------------------
# On training set: Loss 0.412, Accuracy 0.917, Auc 0.946, 418.3 samples/s cuda.
# On validation set: Loss 0.567, Accuracy 0.725, Auc 0.797.
# On test set: Loss 0.580, Accuracy 0.734, Auc 0.768.
# --------------------
# num of repeat: 46
# --------------------
# On training set: Loss 0.410, Accuracy 0.917, Auc 0.918, 478.4 samples/s cuda.
# On validation set: Loss 0.529, Accuracy 0.775, Auc 0.959.
# On test set: Loss 0.616, Accuracy 0.691, Auc 0.782.
# --------------------
# num of repeat: 47
# --------------------
# On training set: Loss 0.475, Accuracy 0.833, Auc 0.905, 400.1 samples/s cuda.
# On validation set: Loss 0.528, Accuracy 0.775, Auc 0.922.
# On test set: Loss 0.612, Accuracy 0.702, Auc 0.752.
# --------------------
# num of repeat: 48
# --------------------
# On training set: Loss 0.398, Accuracy 0.917, Auc 0.940, 402.1 samples/s cuda.
# On validation set: Loss 0.516, Accuracy 0.800, Auc 0.838.
# On test set: Loss 0.633, Accuracy 0.681, Auc 0.733.
# --------------------
# num of repeat: 49
# --------------------
# On training set: Loss 0.449, Accuracy 0.872, Auc 0.894, 485.8 samples/s cuda.
# On validation set: Loss 0.508, Accuracy 0.800, Auc 0.863.
# On test set: Loss 0.597, Accuracy 0.723, Auc 0.752.
# --------------------
# num of repeat: 50
# --------------------
# On training set: Loss 0.474, Accuracy 0.827, Auc 0.894, 429.8 samples/s cuda.
# On validation set: Loss 0.514, Accuracy 0.800, Auc 0.887.
# On test set: Loss 0.577, Accuracy 0.723, Auc 0.762.
# --------------------
# num of repeat: 51
# --------------------
# On training set: Loss 0.535, Accuracy 0.769, Auc 0.831, 432.1 samples/s cuda.
# On validation set: Loss 0.659, Accuracy 0.625, Auc 0.816.
# On test set: Loss 0.669, Accuracy 0.617, Auc 0.721.
# --------------------
# num of repeat: 52
# --------------------
# On training set: Loss 0.357, Accuracy 0.968, Auc 0.959, 461.4 samples/s cuda.
# On validation set: Loss 0.548, Accuracy 0.750, Auc 0.843.
# On test set: Loss 0.604, Accuracy 0.713, Auc 0.744.
# --------------------
# num of repeat: 53
# --------------------
# On training set: Loss 0.428, Accuracy 0.891, Auc 0.918, 449.5 samples/s cuda.
# On validation set: Loss 0.537, Accuracy 0.775, Auc 0.813.
# On test set: Loss 0.700, Accuracy 0.606, Auc 0.610.
# --------------------
# num of repeat: 54
# --------------------
# On training set: Loss 0.453, Accuracy 0.865, Auc 0.901, 437.0 samples/s cuda.
# On validation set: Loss 0.482, Accuracy 0.825, Auc 0.831.
# On test set: Loss 0.652, Accuracy 0.660, Auc 0.751.
# --------------------
# num of repeat: 55
# --------------------
# On training set: Loss 0.469, Accuracy 0.833, Auc 0.912, 460.1 samples/s cuda.
# On validation set: Loss 0.566, Accuracy 0.750, Auc 0.654.
# On test set: Loss 0.606, Accuracy 0.702, Auc 0.737.
# --------------------
# num of repeat: 56
# --------------------
# On training set: Loss 0.558, Accuracy 0.769, Auc 0.845, 422.8 samples/s cuda.
# On validation set: Loss 0.651, Accuracy 0.550, Auc 0.766.
# On test set: Loss 0.636, Accuracy 0.628, Auc 0.717.
# --------------------
# num of repeat: 57
# --------------------
# On training set: Loss 0.489, Accuracy 0.840, Auc 0.916, 423.9 samples/s cuda.
# On validation set: Loss 0.617, Accuracy 0.625, Auc 0.768.
# On test set: Loss 0.607, Accuracy 0.691, Auc 0.736.
# --------------------
# num of repeat: 58
# --------------------
# On training set: Loss 0.429, Accuracy 0.897, Auc 0.935, 389.1 samples/s cuda.
# On validation set: Loss 0.562, Accuracy 0.750, Auc 0.856.
# On test set: Loss 0.613, Accuracy 0.691, Auc 0.766.
# --------------------
# num of repeat: 59
# --------------------
# On training set: Loss 0.445, Accuracy 0.865, Auc 0.914, 532.1 samples/s cuda.
# On validation set: Loss 0.528, Accuracy 0.775, Auc 0.681.
# On test set: Loss 0.608, Accuracy 0.702, Auc 0.670.
# --------------------
# num of repeat: 60
# --------------------
# On training set: Loss 0.437, Accuracy 0.885, Auc 0.923, 487.3 samples/s cuda.
# On validation set: Loss 0.530, Accuracy 0.775, Auc 0.863.
# On test set: Loss 0.586, Accuracy 0.734, Auc 0.747.
# --------------------
# num of repeat: 61
# --------------------
# On training set: Loss 0.408, Accuracy 0.923, Auc 0.929, 423.9 samples/s cuda.
# On validation set: Loss 0.544, Accuracy 0.750, Auc 0.849.
# On test set: Loss 0.593, Accuracy 0.691, Auc 0.725.
# --------------------
# num of repeat: 62
# --------------------
# On training set: Loss 0.438, Accuracy 0.897, Auc 0.918, 421.6 samples/s cuda.
# On validation set: Loss 0.575, Accuracy 0.725, Auc 0.808.
# On test set: Loss 0.613, Accuracy 0.660, Auc 0.749.
# --------------------
# num of repeat: 63
# --------------------
# On training set: Loss 0.446, Accuracy 0.872, Auc 0.925, 438.2 samples/s cuda.
# On validation set: Loss 0.530, Accuracy 0.775, Auc 0.871.
# On test set: Loss 0.614, Accuracy 0.691, Auc 0.742.
# --------------------
# num of repeat: 64
# --------------------
# On training set: Loss 0.363, Accuracy 0.955, Auc 0.963, 449.5 samples/s cuda.
# On validation set: Loss 0.502, Accuracy 0.800, Auc 0.854.
# On test set: Loss 0.577, Accuracy 0.734, Auc 0.754.
# --------------------
# num of repeat: 65
# --------------------
# On training set: Loss 0.507, Accuracy 0.801, Auc 0.902, 467.0 samples/s cuda.
# On validation set: Loss 0.585, Accuracy 0.725, Auc 0.791.
# On test set: Loss 0.643, Accuracy 0.670, Auc 0.744.
# --------------------
# num of repeat: 66
# --------------------
# On training set: Loss 0.367, Accuracy 0.955, Auc 0.960, 400.1 samples/s cuda.
# On validation set: Loss 0.516, Accuracy 0.800, Auc 0.940.
# On test set: Loss 0.601, Accuracy 0.713, Auc 0.797.
# --------------------
# num of repeat: 67
# --------------------
# On training set: Loss 0.620, Accuracy 0.731, Auc 0.823, 399.1 samples/s cuda.
# On validation set: Loss 0.688, Accuracy 0.500, Auc 0.739.
# On test set: Loss 0.648, Accuracy 0.628, Auc 0.675.
# --------------------
# num of repeat: 68
# --------------------
# On training set: Loss 0.533, Accuracy 0.795, Auc 0.852, 430.9 samples/s cuda.
# On validation set: Loss 0.581, Accuracy 0.675, Auc 0.831.
# On test set: Loss 0.638, Accuracy 0.628, Auc 0.716.
# --------------------
# num of repeat: 69
# --------------------
# On training set: Loss 0.513, Accuracy 0.808, Auc 0.871, 450.8 samples/s cuda.
# On validation set: Loss 0.487, Accuracy 0.825, Auc 0.900.
# On test set: Loss 0.649, Accuracy 0.638, Auc 0.730.
# --------------------
# num of repeat: 70
# --------------------
# On training set: Loss 0.419, Accuracy 0.910, Auc 0.952, 485.8 samples/s cuda.
# On validation set: Loss 0.603, Accuracy 0.700, Auc 0.799.
# On test set: Loss 0.635, Accuracy 0.670, Auc 0.766.
# --------------------
# num of repeat: 71
# --------------------
# On training set: Loss 0.410, Accuracy 0.904, Auc 0.937, 464.2 samples/s cuda.
# On validation set: Loss 0.544, Accuracy 0.775, Auc 0.701.
# On test set: Loss 0.614, Accuracy 0.691, Auc 0.726.
# --------------------
# num of repeat: 72
# --------------------
# On training set: Loss 0.482, Accuracy 0.827, Auc 0.875, 428.6 samples/s cuda.
# On validation set: Loss 0.666, Accuracy 0.625, Auc 0.755.
# On test set: Loss 0.609, Accuracy 0.713, Auc 0.726.
# --------------------
# num of repeat: 73
# --------------------
# On training set: Loss 0.372, Accuracy 0.942, Auc 0.961, 426.2 samples/s cuda.
# On validation set: Loss 0.590, Accuracy 0.725, Auc 0.636.
# On test set: Loss 0.603, Accuracy 0.702, Auc 0.706.
# --------------------
# num of repeat: 74
# --------------------
# On training set: Loss 0.374, Accuracy 0.955, Auc 0.973, 418.3 samples/s cuda.
# On validation set: Loss 0.493, Accuracy 0.800, Auc 0.924.
# On test set: Loss 0.567, Accuracy 0.745, Auc 0.788.
# --------------------
# num of repeat: 75
# --------------------
# On training set: Loss 0.377, Accuracy 0.936, Auc 0.951, 434.5 samples/s cuda.
# On validation set: Loss 0.572, Accuracy 0.725, Auc 0.794.
# On test set: Loss 0.592, Accuracy 0.713, Auc 0.782.
# --------------------
# num of repeat: 76
# --------------------
# On training set: Loss 0.355, Accuracy 0.962, Auc 0.947, 416.0 samples/s cuda.
# On validation set: Loss 0.531, Accuracy 0.775, Auc 0.729.
# On test set: Loss 0.560, Accuracy 0.755, Auc 0.716.
# --------------------
# num of repeat: 77
# --------------------
# On training set: Loss 0.342, Accuracy 0.974, Auc 0.960, 457.4 samples/s cuda.
# On validation set: Loss 0.540, Accuracy 0.775, Auc 0.775.
# On test set: Loss 0.629, Accuracy 0.681, Auc 0.750.
# --------------------
# num of repeat: 78
# --------------------
# On training set: Loss 0.395, Accuracy 0.936, Auc 0.943, 423.9 samples/s cuda.
# On validation set: Loss 0.505, Accuracy 0.800, Auc 0.736.
# On test set: Loss 0.613, Accuracy 0.681, Auc 0.714.
# --------------------
# num of repeat: 79
# --------------------
# On training set: Loss 0.433, Accuracy 0.872, Auc 0.932, 438.2 samples/s cuda.
# On validation set: Loss 0.587, Accuracy 0.725, Auc 0.729.
# On test set: Loss 0.649, Accuracy 0.649, Auc 0.750.
# --------------------
# num of repeat: 80
# --------------------
# On training set: Loss 0.484, Accuracy 0.840, Auc 0.899, 461.4 samples/s cuda.
# On validation set: Loss 0.512, Accuracy 0.800, Auc 0.860.
# On test set: Loss 0.626, Accuracy 0.670, Auc 0.715.
# --------------------
# num of repeat: 81
# --------------------
# On training set: Loss 0.421, Accuracy 0.897, Auc 0.926, 460.1 samples/s cuda.
# On validation set: Loss 0.551, Accuracy 0.725, Auc 0.832.
# On test set: Loss 0.650, Accuracy 0.638, Auc 0.710.
# --------------------
# num of repeat: 82
# --------------------
# On training set: Loss 0.611, Accuracy 0.724, Auc 0.804, 445.7 samples/s cuda.
# On validation set: Loss 0.646, Accuracy 0.600, Auc 0.743.
# On test set: Loss 0.638, Accuracy 0.628, Auc 0.718.
# --------------------
# num of repeat: 83
# --------------------
# On training set: Loss 0.381, Accuracy 0.936, Auc 0.947, 488.8 samples/s cuda.
# On validation set: Loss 0.554, Accuracy 0.750, Auc 0.859.
# On test set: Loss 0.612, Accuracy 0.702, Auc 0.791.
# --------------------
# num of repeat: 84
# --------------------
# On training set: Loss 0.468, Accuracy 0.878, Auc 0.910, 456.1 samples/s cuda.
# On validation set: Loss 0.630, Accuracy 0.625, Auc 0.838.
# On test set: Loss 0.594, Accuracy 0.702, Auc 0.743.
# --------------------
# num of repeat: 85
# --------------------
# On training set: Loss 0.481, Accuracy 0.840, Auc 0.900, 478.4 samples/s cuda.
# On validation set: Loss 0.577, Accuracy 0.725, Auc 0.923.
# On test set: Loss 0.649, Accuracy 0.670, Auc 0.744.
# --------------------
# num of repeat: 86
# --------------------
# On training set: Loss 0.461, Accuracy 0.872, Auc 0.939, 759.4 samples/s cuda.
# On validation set: Loss 0.564, Accuracy 0.750, Auc 0.805.
# On test set: Loss 0.596, Accuracy 0.723, Auc 0.742.
# --------------------
# num of repeat: 87
# --------------------
# On training set: Loss 0.411, Accuracy 0.910, Auc 0.929, 539.4 samples/s cuda.
# On validation set: Loss 0.617, Accuracy 0.650, Auc 0.791.
# On test set: Loss 0.572, Accuracy 0.723, Auc 0.797.
# --------------------
# num of repeat: 88
# --------------------
# On training set: Loss 0.471, Accuracy 0.827, Auc 0.907, 472.6 samples/s cuda.
# On validation set: Loss 0.498, Accuracy 0.825, Auc 0.712.
# On test set: Loss 0.596, Accuracy 0.702, Auc 0.735.
# --------------------
# num of repeat: 89
# --------------------
# On training set: Loss 0.357, Accuracy 0.968, Auc 0.968, 501.4 samples/s cuda.
# On validation set: Loss 0.517, Accuracy 0.800, Auc 0.802.
# On test set: Loss 0.622, Accuracy 0.691, Auc 0.703.
# --------------------
# num of repeat: 90
# --------------------
# On training set: Loss 0.380, Accuracy 0.929, Auc 0.963, 422.8 samples/s cuda.
# On validation set: Loss 0.529, Accuracy 0.750, Auc 0.891.
# On test set: Loss 0.566, Accuracy 0.755, Auc 0.781.
# --------------------
# num of repeat: 91
# --------------------
# On training set: Loss 0.496, Accuracy 0.840, Auc 0.894, 416.0 samples/s cuda.
# On validation set: Loss 0.542, Accuracy 0.775, Auc 0.871.
# On test set: Loss 0.609, Accuracy 0.713, Auc 0.752.
# --------------------
# num of repeat: 92
# --------------------
# On training set: Loss 0.483, Accuracy 0.846, Auc 0.896, 575.1 samples/s cuda.
# On validation set: Loss 0.546, Accuracy 0.775, Auc 0.835.
# On test set: Loss 0.604, Accuracy 0.670, Auc 0.782.
# --------------------
# num of repeat: 93
# --------------------
# On training set: Loss 0.425, Accuracy 0.897, Auc 0.932, 421.6 samples/s cuda.
# On validation set: Loss 0.480, Accuracy 0.825, Auc 0.894.
# On test set: Loss 0.573, Accuracy 0.734, Auc 0.773.
# --------------------
# num of repeat: 94
# --------------------
# On training set: Loss 0.484, Accuracy 0.827, Auc 0.901, 423.9 samples/s cuda.
# On validation set: Loss 0.535, Accuracy 0.750, Auc 0.868.
# On test set: Loss 0.631, Accuracy 0.681, Auc 0.709.
# --------------------
# num of repeat: 95
# --------------------
# On training set: Loss 0.387, Accuracy 0.923, Auc 0.979, 452.1 samples/s cuda.
# On validation set: Loss 0.621, Accuracy 0.675, Auc 0.731.
# On test set: Loss 0.605, Accuracy 0.702, Auc 0.780.
# --------------------
# num of repeat: 96
# --------------------
# On training set: Loss 0.580, Accuracy 0.731, Auc 0.872, 683.1 samples/s cuda.
# On validation set: Loss 0.663, Accuracy 0.575, Auc 0.776.
# On test set: Loss 0.638, Accuracy 0.638, Auc 0.718.
# --------------------
# num of repeat: 97
# --------------------
# On training set: Loss 0.361, Accuracy 0.962, Auc 0.961, 443.1 samples/s cuda.
# On validation set: Loss 0.506, Accuracy 0.825, Auc 0.828.
# On test set: Loss 0.599, Accuracy 0.702, Auc 0.753.
# --------------------
# num of repeat: 98
# --------------------
# On training set: Loss 0.579, Accuracy 0.782, Auc 0.843, 407.4 samples/s cuda.
# On validation set: Loss 0.642, Accuracy 0.575, Auc 0.764.
# On test set: Loss 0.632, Accuracy 0.628, Auc 0.714.
# --------------------
# num of repeat: 99
# --------------------
# On training set: Loss 0.424, Accuracy 0.897, Auc 0.949, 425.1 samples/s cuda.
# On validation set: Loss 0.501, Accuracy 0.800, Auc 0.801.
# On test set: Loss 0.612, Accuracy 0.702, Auc 0.673.
# --------------------
# One layer without smote with mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.433, Accuracy 0.887, Auc 0.925, 453.5 samples/s cuda.
# On validation set: Loss 0.552, Accuracy 0.744, Auc 0.822.
# On test set: Loss 0.609, Accuracy 0.694, Auc 0.742.

# %%
t = time.localtime()
print(str(t.tm_hour)+':'+str(t.tm_min))
# Out:
# 18:57
