# %%
from myclass import *
# warnings.filterwarnings("ignore", category=DeprecationWarning) 
# warnings.filterwarnings('ignore')

#################################################
#------------------ Load Data ------------------#
#################################################

patient_info = pd.read_excel('Dataset.xlsx','patient_information',engine='openpyxl')
cnv_5mb_counts = pd.read_excel('Dataset.xlsx','cnv_5mb_counts',engine='openpyxl').loc[:,['patientID','cnv_Count']].rename(columns={'cnv_Count': 'cnv_Count_5mb'})
cnv_gistic_counts = pd.read_excel('Dataset.xlsx','cnv_gistic_counts',engine='openpyxl').loc[:,['patientID','cnv_Count']].rename(columns={'cnv_Count': 'cnv_Count_gistic'})
snv = pd.read_excel('Dataset.xlsx','snv_feature_matrix',engine='openpyxl')
clinical_info = pd.read_excel('Clinical Feature.xlsx','Supplementary Table 2',engine='openpyxl').drop(['Subject type', 'Subject group', 'Stage (AJCC v7)', 'Pack-years'], axis=1)
clinical_info = clinical_info.rename(columns={'Histology':'Histology label'})

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

seed = 1105
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ## Data

# %%
##################################################
#-------------- Data Preprocessing -------------#
################################################

#----- Parameters -----#
num_patients_train = len(patient_info[patient_info.split_info == 'training'])# number of patients in training set
num_patients_test = len(patient_info[patient_info.split_info == 'validation'])# number of patients in training set
max_variats = 84 # max number of variation for each patient
num_steps = 84
# num_feature_not_snv = 8
num_var_attri = snv.shape[1] # number of attributes to discribe each variation
scale = Normalization('MinMaxLogScale') # choose normalizer

# #----- OneHot categorical variable of SNV-----#
one_hot,_,_ = OneHotText(snv['Gene'])
snv['Gene'] = [one_hot[i] for i in range(len(one_hot))]


one_hot,_,_ = OneHotText(snv['Variant.type'])
snv['Variant.type'] = [one_hot[i] for i in range(len(one_hot))]

snv['BaseConversion'] = snv['Tumor.allele']+snv['Ref..allele']
one_hot,_,_ = OneHotText(snv['BaseConversion'])
snv['BaseConversion'] = [one_hot[i] for i in range(len(one_hot))]

one_hot,_,_ = OneHotText(snv['Chr'])
snv['Chr'] = [one_hot[i] for i in range(len(one_hot))]

one_hot,_,_ = OneHotText(snv['germline_reads'])
snv['germline_reads'] = [one_hot[i] for i in range(len(one_hot))]

# drop coded feature
snv = snv.drop(['Tumor.allele', 'Ref..allele', 'variant', 'lookup', 
                'Case', 'cohort', 'A>CUnstranded', 'A>GUnstranded',
                'A>TUnstranded', 'C>AUnstranded', 'C>GUnstranded', 
                'G>AUnstranded', 'pass_basic_QC', 'blacklist1_oncogenes',
                'pass_basic_QC_coding'], axis=1)

# snv feature list to scale
list_to_normalization = ['Position','Percent.mutant.allele', 'variant_count_norm','ontarget_shoulder_tile_mut_count_norm', 
                         'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p',
                         'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases',
                         'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth','gnomad_maxAF',
                         'size_selected_adjustment','germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval',
                         'sum_log10_frag_size_enrich_score', 'germline_depth_at_position', 'cosmic_total_count', 'cosmic_lung_count']

# %%
snv_before = deepcopy(snv)

# %%
#----- OneHot categorical variable of clinical features ----#
clinical_info = pd.read_excel('Clinical Feature.xlsx','Supplementary Table 2',engine='openpyxl').drop(['Subject type', 'Subject group', 'Stage (AJCC v7)', 'Pack-years'], axis=1)
clinical_info = clinical_info.rename(columns={'Histology':'Histology label'})

one_hot,_,_ = OneHotText(clinical_info['Sex'])
clinical_info['Sex'] = deepcopy(one_hot)

one_hot,_,_ = OneHotText(clinical_info['Histology label'])
clinical_info['Histology label'] = deepcopy(one_hot)

one_hot,_,_ = OneHotText(clinical_info['Smoker'])
clinical_info['Smoker'] = deepcopy(one_hot)

# %%
dataset = patient_info.set_index('patientID').\
join(cnv_5mb_counts.set_index('patientID')).join(cnv_gistic_counts.set_index('patientID')).drop('SampleID', axis=1).\
join(clinical_info.set_index('Patient ID'))

# %%
##################################################
#-------------- Obtain Training Set -------------#
################################################
train_x = deepcopy(dataset[dataset.split_info == 'training'])

#----- clinical features normalization -----#
clinical_list_to_normalization = ['Age (years)', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)']
train_x = normalizer(train_x, clinical_list_to_normalization, scale)
#----- cnv normalization -----#
cnv_list_to_normalization = ['cnv_Count_5mb','cnv_Count_gistic']
train_x = normalizer(train_x, cnv_list_to_normalization, scale)
#----- snv normalization -----#
train_snv = deepcopy(snv[['SU2'not in i for i in snv['patientID']]])
train_snv = normalizer(train_snv, list_to_normalization, scale)
train_x = GroupAndExtractSNV(train_x, train_snv, num_steps)
    
#----- Label -----#    
train_x['label'] = [1 if 'LUP' in train_x.index[i] else 0 for i in range(train_x.shape[0])]
one_hot,_,_ = OneHotText(train_x['Stage_group'])
train_x['stage_label'] = [one_hot[i] for i in range(len(one_hot))]
train_x = train_x.drop(['Stage_group'], axis=1)
    
# # x.to_excel("preprocessed_training_dataset.xlsx")

# %%
train_x['snv'][0].shape
# Out:
# (84, 267)

# %%
train_x_before = deepcopy(train_x)

# %%
##################################################
#-------------- Obtain Test Set -------------#
################################################

test_x = deepcopy(dataset[dataset.split_info == 'validation'])

#----- clinical features normalization -----#
test_x = normalizer(test_x, clinical_list_to_normalization, scale)
#----- cnv normalization -----#
test_x = normalizer(test_x, cnv_list_to_normalization, scale)
#----- snv normalization -----#
test_snv = deepcopy(snv[['SU2' in i for i in snv['patientID']]])
test_snv = normalizer(test_snv, list_to_normalization, scale)
test_x = GroupAndExtractSNV(test_x, test_snv, num_steps)
    
#----- Label -----#    
test_x['label'] = [1 if 'SU2CS' in test_x.index[i] else 0 for i in range(test_x.shape[0])]
one_hot,_,_ = OneHotText(test_x['Stage_group'])
test_x['stage_label'] = [one_hot[i] for i in range(len(one_hot))]
test_x = test_x.drop(['Stage_group'], axis=1)
    
# # x.to_excel("preprocessed_testing_dataset.xlsx")

# %% [markdown]
# # AutoML based on Baysian optimization

# %%
class AutoCancer(nn.Module):
    """
    Class description: AutoCancer with Bi-LSTM and Transformer
    
    """
    #----- Define all layers -----#
    def __init__(self, num_inputs_lstm, num_lstm_hiddens, num_lstm_layers, lstm_bidirectional, initial_dropout,
               num_feature_not_snv, num_output_nodes, num_fc_layers, device, head, trsf_num_layer, trsf_dropout,
                 trsf_hidden, shape, act = nn.Sigmoid(), **kwargs):
        super(AutoCancer, self).__init__(**kwargs)

        #--- LSTM layer ---#
        if num_lstm_layers == 1:
            lstm_dropout = 0
        else:
            lstm_dropout = initial_dropout
        self.lstm = nn.LSTM(num_inputs_lstm,
                            num_lstm_hiddens,
                            num_layers=num_lstm_layers,
                            bidirectional=lstm_bidirectional,
                            dropout=lstm_dropout,
                            batch_first=True)
        #--- Transformer ---#
        len_sentence,trsf_imput_dim, trsf_hidden_dim  = shape[0], shape[1], trsf_hidden*head
        
        self.attention_model = AttentionModel(d_input=trsf_imput_dim, d_model=trsf_hidden_dim, d_ff=2*trsf_hidden_dim, head=head, 
                                              num_layer=trsf_num_layer, dropout=trsf_dropout)
        self.trsf_fc = nn.Linear(trsf_hidden_dim, 1)        
        
        for p in self.attention_model.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)     
        
        #--- Fully connected layers ---#
        self.num_fc_layers = num_fc_layers
        num_fc_input = num_lstm_hiddens * 2+num_feature_not_snv+len_sentence
        if num_fc_layers == 1:
            self.fc0 = nn.Linear(num_fc_input, num_output_nodes)
        else:
            # the first fc layer
            self.fc0 = nn.Linear(num_fc_input, int(ceil(num_fc_input/2)))
            self.dropout0 = nn.Dropout(1.1*initial_dropout)
            if num_fc_layers == 2:
                # the last fc layer when num_fc_layers == 2
                self.fc1 = nn.Linear(int(ceil(num_fc_input/2)), num_output_nodes)
            else:
                # the middle fc layer
                for i in range(1,num_fc_layers-1):
                    tmp_input = int(ceil(num_fc_input/2**i))
                    tmp_output = int(ceil(num_fc_input/2**(i+1)))
                    exec('self.fc{} = nn.Linear(tmp_input, tmp_output)'.format(i))
                    if i < ceil(num_fc_layers/2) and 1.1**(i+1)*initial_dropout < 1:
                        exec('self.dropout{} = nn.Dropout(1.1**(i+1)*initial_dropout)'.format(i))
                    elif i >= ceil(num_fc_layers/2) and 1.1**(num_fc_layers-1-i)*initial_dropout < 1:
                        exec('self.dropout{} = nn.Dropout(1.1**(num_fc_layers-1-i)*initial_dropout)'.format(i))
                    else:
                        exec('self.dropout{} = nn.Dropout(0.5)'.format(i))
                # the last fc layer
                exec('self.fc{} = nn.Linear(tmp_output, num_output_nodes)'.format(i+1))
            
        #--- Activation function ---#
        self.act = act
    
    #----- Forward -----#
    def forward(self, x_snv, x_other):
        # x_snv size:  [batch size, sent_length, feature_dim]
        
        norm_output = x_snv.permute(0,2,1)
       
        #--- LSTM layer ---#
        lstm_output, (hidden_state, cell) = self.lstm(norm_output.permute(0,2,1))# hidden size:  [num layersa * num directions, batch size, hid dim]
        #--- Transformer layer ---#
        trsf_output = torch.squeeze(self.trsf_fc(self.attention_model(x_snv)))
        
        #--- Fully connected layers ---#
        #--- Joins the final forward and reverse hidden states ---#
        hidden_state = torch.cat((hidden_state[-2,:,:], hidden_state[-1,:,:]), dim = 1)
        hidden_dense = torch.cat((hidden_state, x_other), dim = 1)
        hidden_dense = torch.cat((hidden_dense, trsf_output), dim = 1)
        if self.num_fc_layers == 1:
            outputs = self.fc0(hidden_dense)
        else:
            # the first fc layer
            outputs = self.act(self.dropout0(self.fc0(hidden_dense)))
            if self.num_fc_layers == 2:
                # the last fc layer when num_fc_layers == 2
                outputs = self.fc1(outputs)
            else:
                # the middle fc layer
                for i in range(1,self.num_fc_layers-1):
                    outputs = eval('self.act(self.dropout{}(self.fc{}(outputs)))'.format(i,i))
                # the last fc layer
                outputs = eval('self.fc{}(outputs)'.format(i+1))
            
        return outputs.softmax(dim=1)

# %%
def train_val_test(num_inputs_lstm, num_lstm_hiddens, num_lstm_layers, lstm_bidirectional, lstm_dropout, num_feature_not_snv, 
                   num_fc_layers, batch_size, lr, patience, num_outer_split, frac_inner_val, train_x, num_epochs, device, head, 
                   trsf_num_layer,  trsf_dropout, trsf_hidden):
    shape = train_x['snv'][0].shape
    train_kf = []
    val_kf = []
    test_kf = []
    KF = StratifiedKFold(num_outer_split, shuffle=True)
    for train_index, sub_test_index in KF.split(train_x, train_x['label']):
        sub_train_index, sub_val_index = next(StratifiedShuffleSplit(n_splits=1,test_size=frac_inner_val).
                                               split(train_x.iloc[train_index],train_x.iloc[train_index]['label']))

        #---  Seperate traing set, validation set and test set ---#
        sub_train = Resampler(train_x.iloc[sub_train_index][:], train_x.iloc[sub_train_index]['label'])
        train_iter = BatchDataGeneration(sub_train, batch_size, shuffle=True)
        val_iter = BatchDataGeneration(train_x.iloc[sub_val_index][:], batch_size, shuffle=True)
        test_iter = BatchDataGeneration(train_x.iloc[sub_test_index][:], batch_size, shuffle=True)


        #-----  Instantiate model -----#
        
        model = AutoCancer(num_inputs_lstm, num_lstm_hiddens, num_lstm_layers, lstm_bidirectional, lstm_dropout,
                                     num_feature_not_snv, num_output_nodes, num_fc_layers, device, head, trsf_num_layer, 
                                     trsf_dropout, trsf_hidden, shape)
        model = model.to(device)

        model.apply(init_weights)

        #-----  Loss -----#
        loss = nn.CrossEntropyLoss(reduction="none")
        loss = loss.to(device)

        #--- Define optimizer ---#
        
        optimizer = torch.optim.Adam(model.parameters(), lr)
        
        #-----  Instantiate EarlyStopping -----#
        early_stopping = EarlyStopping(patience, verbose=False)

        train_loss, train_acc, train_auc, train_speed, val_loss, val_acc, val_auc = train_evaluate(
            model, train_iter, val_iter, loss, optimizer, early_stopping, num_epochs, device)
        
        model.eval()
        test_loss, test_acc, test_auc = evaluate(model, test_iter, loss, device)
        train_kf.append([train_loss, train_acc, train_auc, train_speed])
        val_kf.append([val_loss, val_acc, val_auc])
        test_kf.append([test_loss, test_acc, test_auc])
    return train_kf, val_kf, test_kf

# %%
# ---------------------------------------------------#   
#    Parameter Tuning with Bayesian optimization    #
#--------------------------------------------------# 
num_outer_split = 5
frac_inner_val = 0.25
num_output_nodes, num_epochs = 2, 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


lstm_bidirectional = True
best_score = 100
batch_size = 64
snv_to_select = snv.drop('patientID', axis=1).columns
other_feature_to_select = train_x.drop(['split_info', 'Histology label', 'label', 'stage_label', 'snv'], axis=1).columns
num_feature_to_select = len(snv_to_select) + len(other_feature_to_select)


##---   Define search space   ---##
# The list of hyper-parameters we want to optimize. For each one we define the
# bounds, the corresponding parameter name, as well as how to
# sample values from that dimension (`'log-uniform'` for the learning rate)

search_spaces = [Integer(1,2**10-1, name = 'ten_int_selected_features'),
                 Integer(1,2**10-1, name = 'twenty_int_selected_features'),
                 Integer(1,2**10-1, name = 'thirty_int_selected_features'),
                 Integer(1,2**7-1, name = 'thirty_seven_selected_features'),
                 Integer(1,2**9-1, name = 'forty_six_int_selected_features'),
                 Integer(1,10, name = 'num_lstm_layers'),
                 Real(1e-1, 0.5, prior='log-uniform', name = 'lstm_dropout'),
                 Categorical([64,128,256,512], transform = 'identity', name = 'num_lstm_hiddens'),
                 Real(1e-3, 1e-1, prior='log-uniform', name = 'lr'),
                 Integer(1,10, name = 'patience'),
                 Integer(1,10, name = 'num_fc_layers'),
                 Categorical([2,4,6,8,10], name = 'head'),
                 Integer(1,10, name = 'trsf_num_layer'),
                 Real(1e-1, 0.5, prior='log-uniform', name = 'trsf_dropout'),
                 Integer(1,10, name = 'trsf_hidden')
                ]

@use_named_args(search_spaces)
def masked_objective(ten_int_selected_features, twenty_int_selected_features, thirty_int_selected_features, thirty_seven_selected_features,
                     forty_six_int_selected_features, num_lstm_layers, lstm_dropout, num_lstm_hiddens, lr, patience, num_fc_layers,
                     head, trsf_num_layer, trsf_dropout, trsf_hidden):
    global best_score, snv_to_select, other_feature_to_select
    #---   Decoding feature selection results   ---#
    bin_selected_features = bin(ten_int_selected_features)[2:]
    for i in range(10-len(bin_selected_features)):
        bin_selected_features = '0' + bin_selected_features
        
    tmp_bin_selected_features = bin(twenty_int_selected_features)[2:]
    for i in range(10-len(tmp_bin_selected_features)):
        tmp_bin_selected_features = '0' + tmp_bin_selected_features
    bin_selected_features = bin_selected_features+ tmp_bin_selected_features
    
    tmp_bin_selected_features = bin(thirty_int_selected_features)[2:]
    for i in range(10-len(tmp_bin_selected_features)):
        tmp_bin_selected_features = '0' + tmp_bin_selected_features
    bin_selected_features = bin_selected_features+ tmp_bin_selected_features
    
    tmp_bin_selected_features = bin(thirty_seven_selected_features)[2:]
    for i in range(7-len(tmp_bin_selected_features)):
        tmp_bin_selected_features = '0' + tmp_bin_selected_features
    bin_selected_features = bin_selected_features+ tmp_bin_selected_features

    snv_selected = [snv_to_select[i] for i in range(len(snv_to_select)) if bin_selected_features[i] == '1']
    snv_selected.append('patientID')
    
    
    
    bin_selected_features = bin(forty_six_int_selected_features)[2:]
    for i in range(9-len(bin_selected_features)):
        bin_selected_features = '0' + bin_selected_features
        
    
    other_feature_selected = [other_feature_to_select[i] for i in range(len(other_feature_to_select)) if bin_selected_features[i] == '1']
    other_feature_selected.append('label')
    new_train_snv = deepcopy(train_snv[snv_selected])
    new_train_x = deepcopy(train_x[other_feature_selected])
    new_train_x = NewGroupAndExtractSNV(new_train_x, new_train_snv, num_steps)
    
    num_inputs_lstm = new_train_x.iloc[0]['snv'].shape[1]
    
    num_feature_not_snv = len(other_feature_selected)-1
    train_all, val_all, test_all = train_val_test(num_inputs_lstm, num_lstm_hiddens, num_lstm_layers, lstm_bidirectional, lstm_dropout, 
                                                  num_feature_not_snv, num_fc_layers, batch_size, lr, patience, num_outer_split, 
                                                  frac_inner_val, new_train_x, num_epochs, device, head, trsf_num_layer,  trsf_dropout, trsf_hidden)
        
    train_all = np.array(train_all)
    val_all = np.array(val_all)
    test_all = np.array(test_all)
    train_loss, train_acc, train_auc, train_speed = train_all[:,0], train_all[:,1], train_all[:,2], train_all[:,3]
    val_loss, val_acc, val_auc = val_all[:,0], val_all[:,1], val_all[:,2]
    test_loss, test_acc, test_auc = test_all[:,0], test_all[:,1], test_all[:,2]    
    print('-'*20)
    print('One layer without smote without mask with early stopping under k-fold cv best model:')
    print('-'*20)
    print(f'On training set: Loss {train_loss.mean():.3f}, Accuracy {train_acc.mean():.3f}, Auc {train_auc.mean():.3f}, {train_speed.mean():.1f} samples/s {str(device)}.')
    print(f'On validation set: Loss {val_loss.mean():.3f}, Accuracy {val_acc.mean():.3f}, Auc {val_auc.mean():.3f}.')
    print(f'On test set: Loss {test_loss.mean():.3f}, Accuracy {test_acc.mean():.3f}, Auc {test_auc.mean():.3f}.')
    
    train_score = -train_auc.mean()
    val_score = -val_auc.mean()
    test_score = -test_auc.mean()
    
    tmp = test_score+val_score
    
    if tmp < best_score:
        best_score = tmp
        print('*'*20)
        print("""Best parameters:
        snv_selected = %s
        other_feature_selected = %s
        num_lstm_layers = %d
        lstm_dropout = %f
        num_lstm_hiddens = %d
        lr = %f
        patience = %d
        num_fc_layers = %d
        head = %d
        trsf_num_layer = %d
        trsf_dropout = %f
        trsf_hidden = %d""" % (snv_selected, other_feature_selected, num_lstm_layers, lstm_dropout, num_lstm_hiddens, lr, patience, 
                               num_fc_layers, head, trsf_num_layer, trsf_dropout, trsf_hidden))
        print('*'*20)
    else:
        print("""Current parameters:
        snv_selected = %s
        other_feature_selected = %s
        num_lstm_layers = %d
        lstm_dropout = %f
        num_lstm_hiddens = %d
        lr = %f
        patience = %d
        num_fc_layers = %d
        head = %d
        trsf_num_layer = %d
        trsf_dropout = %f
        trsf_hidden = %d""" % (snv_selected, other_feature_selected, num_lstm_layers, lstm_dropout, num_lstm_hiddens, lr, patience, 
                               num_fc_layers, head, trsf_num_layer, trsf_dropout, trsf_hidden))
        
    frac_feature = 0.05*(len(other_feature_selected) - 1)/ len(other_feature_to_select)+ 0.01*len(snv_selected)/len(snv_to_select)
    
    return (0.5*tmp+ frac_feature)

# %%
t = time.localtime()
print(str(t.tm_hour)+':'+str(t.tm_min))
# Out:
# 21:23

# %%
masked_gp = gp_minimize(masked_objective, search_spaces, n_calls=100, random_state=920,acq_func="EI",verbose=True, n_jobs=-1)

"Best score=%.4f" % masked_gp.fun

#---   Decoding feature selection results   ---#
bin_selected_features = bin(masked_gp.x[0])[2:]
for i in range(10-len(bin_selected_features)):
    bin_selected_features = '0' + bin_selected_features

tmp_bin_selected_features = bin(masked_gp.x[1])[2:]
for i in range(10-len(tmp_bin_selected_features)):
    tmp_bin_selected_features = '0' + tmp_bin_selected_features
bin_selected_features = bin_selected_features+ tmp_bin_selected_features

tmp_bin_selected_features = bin(masked_gp.x[2])[2:]
for i in range(10-len(tmp_bin_selected_features)):
    tmp_bin_selected_features = '0' + tmp_bin_selected_features
bin_selected_features = bin_selected_features+ tmp_bin_selected_features

tmp_bin_selected_features = bin(masked_gp.x[3])[2:]
for i in range(7-len(tmp_bin_selected_features)):
    tmp_bin_selected_features = '0' + tmp_bin_selected_features
bin_selected_features = bin_selected_features+ tmp_bin_selected_features

snv_selected = [snv_to_select[i] for i in range(len(snv_to_select)) if bin_selected_features[i] == '1']
#     print(snv_selected)
#     if snv_selected == []:
#         snv_selected = ['Gene']
snv_selected.append('patientID')

bin_selected_features = bin(masked_gp.x[4])[2:]
for i in range(9-len(bin_selected_features)):
    bin_selected_features = '0' + bin_selected_features


other_feature_selected = [other_feature_to_select[i] for i in range(len(other_feature_to_select)) if bin_selected_features[i] == '1']
other_feature_selected.append('label')
##---   Print parameters   ---##
print("""Best parameters:
snv_selected = %s
other_feature_selected = %s
num_lstm_layers = %d
lstm_dropout = %f
num_lstm_hiddens = %d
lr = %f
patience = %d
num_fc_layers = %d
head = %d
trsf_num_layer = %d
trsf_dropout = %f
trsf_hidden = %d""" % (snv_selected, other_feature_selected, masked_gp.x[5],masked_gp.x[6], masked_gp.x[7],
                    masked_gp.x[8], masked_gp.x[9], masked_gp.x[10], masked_gp.x[11],
                    masked_gp.x[12], masked_gp.x[13], masked_gp.x[14]))

from skopt.plots import plot_convergence

fig = plt.figure()

ax1=plot_convergence(masked_gp)
# ax1 = plot_objective(res)
# ax1.savefig("bys.png")A
# ax1.savefig("bys.eps")
plt.savefig(str(t.tm_mon)+'-'+str(t.tm_mday)+'-'+str(t.tm_hour)+'AutoCancer.png')
plt.savefig(str(t.tm_mon)+'-'+str(t.tm_mday)+'-'+str(t.tm_hour)+'AutoCancer.eps')
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.696, Accuracy 0.497, Auc 0.518, 139.2 samples/s cuda.
# On validation set: Loss 0.688, Accuracy 0.588, Auc 0.500.
# On test set: Loss 0.683, Accuracy 0.650, Auc 0.500.
# ********************
# Best parameters:
#         snv_selected = ['Gene', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'normalized_depth', 'gnomad_maxAF', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'tumor_adjudicated', 'cosmic_total_count', 'intersect_unpadded_selector', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Sex', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         num_lstm_layers = 8
#         lstm_dropout = 0.158584
#         num_lstm_hiddens = 256
#         lr = 0.027098
#         patience = 2
#         num_fc_layers = 10
#         head = 6
#         trsf_num_layer = 5
#         trsf_dropout = 0.494721
#         trsf_hidden = 7
# ********************
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 41.8731
# Function value obtained: -0.4660
# Current minimum: -0.4660
# Iteration No: 2 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.624, Accuracy 0.641, Auc 0.635, 209.9 samples/s cuda.
# On validation set: Loss 0.664, Accuracy 0.556, Auc 0.795.
# On test set: Loss 0.628, Accuracy 0.594, Auc 0.887.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Gene', 'pass_split_1yes', 'duplex_reads', 'watsoncrickfisher.p', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'normalized_depth', 'base_change_transition', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'has_matched_tumor', 'intersect_unpadded_selector', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Age (years)', 'Smoker', 'Plasma volume used', 'label']
#         num_lstm_layers = 5
#         lstm_dropout = 0.261983
#         num_lstm_hiddens = 64
#         lr = 0.004399
#         patience = 7
#         num_fc_layers = 5
#         head = 6
#         trsf_num_layer = 6
#         trsf_dropout = 0.363860
#         trsf_hidden = 8
# ********************
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 161.6003
# Function value obtained: -0.8140
# Current minimum: -0.8140
# Iteration No: 3 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.703, Accuracy 0.475, Auc 0.440, 217.1 samples/s cuda.
# On validation set: Loss 0.699, Accuracy 0.481, Auc 0.528.
# On test set: Loss 0.704, Accuracy 0.412, Auc 0.481.
# Current parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'pass_split_1yes', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_num_non_ref_bases', 'gnomad_maxAF', 'size_selected_adjustment', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'tumor_adjudicated', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         num_lstm_layers = 4
#         lstm_dropout = 0.120688
#         num_lstm_hiddens = 64
#         lr = 0.049988
#         patience = 5
#         num_fc_layers = 4
#         head = 10
#         trsf_num_layer = 8
#         trsf_dropout = 0.153185
#         trsf_hidden = 7
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 39.0809
# Function value obtained: -0.4721
# Current minimum: -0.8140
# Iteration No: 4 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.489, Auc 0.509, 123.9 samples/s cuda.
# On validation set: Loss 0.700, Accuracy 0.438, Auc 0.500.
# On test set: Loss 0.708, Accuracy 0.350, Auc 0.500.
# Current parameters:
#         snv_selected = ['Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'duplex_reads', 'watsoncrickfisher.p', 'mean_norm_varpos', 'variant_norm_bc_fam_size', 'normalized_depth', 'size_selected_adjustment', 'LUNG_driver', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'tumor_adjudicated', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.373016
#         num_lstm_hiddens = 128
#         lr = 0.040125
#         patience = 5
#         num_fc_layers = 8
#         head = 8
#         trsf_num_layer = 4
#         trsf_dropout = 0.245258
#         trsf_hidden = 2
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 48.6753
# Function value obtained: -0.4626
# Current minimum: -0.8140
# Iteration No: 5 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.627, Accuracy 0.670, Auc 0.677, 193.5 samples/s cuda.
# On validation set: Loss 0.609, Accuracy 0.637, Auc 0.885.
# On test set: Loss 0.601, Accuracy 0.619, Auc 0.879.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'has_matched_tumor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         num_lstm_layers = 6
#         lstm_dropout = 0.394355
#         num_lstm_hiddens = 64
#         lr = 0.001565
#         patience = 5
#         num_fc_layers = 4
#         head = 10
#         trsf_num_layer = 4
#         trsf_dropout = 0.171763
#         trsf_hidden = 6
# ********************
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 92.1024
# Function value obtained: -0.8387
# Current minimum: -0.8387
# Iteration No: 6 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.710, Accuracy 0.509, Auc 0.517, 159.2 samples/s cuda.
# On validation set: Loss 0.734, Accuracy 0.487, Auc 0.636.
# On test set: Loss 0.728, Accuracy 0.487, Auc 0.631.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'variant_count_norm', 'pass_split_1yes', 'watsoncrickfisher.p', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'base_change_transition', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'tumor_adjudicated', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         num_lstm_layers = 5
#         lstm_dropout = 0.203604
#         num_lstm_hiddens = 64
#         lr = 0.022238
#         patience = 4
#         num_fc_layers = 3
#         head = 4
#         trsf_num_layer = 9
#         trsf_dropout = 0.143004
#         trsf_hidden = 10
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 37.5859
# Function value obtained: -0.6102
# Current minimum: -0.8387
# Iteration No: 7 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.500, Auc 0.503, 104.6 samples/s cuda.
# On validation set: Loss 0.702, Accuracy 0.425, Auc 0.542.
# On test set: Loss 0.707, Accuracy 0.350, Auc 0.612.
# Current parameters:
#         snv_selected = ['Chr', 'Gene', 'variant_count_norm', 'pass_split_1yes', 'duplex_reads', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'normalized_depth', 'base_change_transition', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'cfdnabg_Bayesian_pval', 'has_matched_tumor', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 9
#         lstm_dropout = 0.472313
#         num_lstm_hiddens = 512
#         lr = 0.005119
#         patience = 8
#         num_fc_layers = 7
#         head = 4
#         trsf_num_layer = 5
#         trsf_dropout = 0.165805
#         trsf_hidden = 9
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 81.8860
# Function value obtained: -0.5329
# Current minimum: -0.8387
# Iteration No: 8 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.813, Accuracy 0.500, Auc 0.492, 153.2 samples/s cuda.
# On validation set: Loss 0.851, Accuracy 0.463, Auc 0.500.
# On test set: Loss 0.788, Accuracy 0.525, Auc 0.500.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Percent.mutant.allele', 'pass_split_1yes', 'duplex_reads', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'germline_reads', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Sex', 'Smoker', 'snv_valid_len', 'label']
#         num_lstm_layers = 7
#         lstm_dropout = 0.238178
#         num_lstm_hiddens = 128
#         lr = 0.099607
#         patience = 7
#         num_fc_layers = 2
#         head = 6
#         trsf_num_layer = 7
#         trsf_dropout = 0.300045
#         trsf_hidden = 8
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 418.8747
# Function value obtained: -0.4724
# Current minimum: -0.8387
# Iteration No: 9 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.693, Accuracy 0.511, Auc 0.531, 271.8 samples/s cuda.
# On validation set: Loss 0.690, Accuracy 0.556, Auc 0.615.
# On test set: Loss 0.686, Accuracy 0.650, Auc 0.663.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Percent.mutant.allele', 'variant_count_norm', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_depth_at_position', 'cosmic_total_count', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Sex', 'Plasma volume used', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.227724
#         num_lstm_hiddens = 512
#         lr = 0.003219
#         patience = 7
#         num_fc_layers = 9
#         head = 4
#         trsf_num_layer = 7
#         trsf_dropout = 0.450422
#         trsf_hidden = 6
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 90.6663
# Function value obtained: -0.6107
# Current minimum: -0.8387
# Iteration No: 10 started. Evaluating function at random point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.498, Auc 0.513, 131.1 samples/s cuda.
# On validation set: Loss 0.701, Accuracy 0.425, Auc 0.500.
# On test set: Loss 0.707, Accuracy 0.350, Auc 0.500.
# Current parameters:
#         snv_selected = ['Position', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_num_non_ref_bases', 'variant_norm_bc_fam_size', 'gnomad_maxAF', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'germline_depth_at_position', 'tumor_adjudicated', 'intersect_unpadded_selector', 'cosmic_lung_count', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.243829
#         num_lstm_hiddens = 64
#         lr = 0.091309
#         patience = 2
#         num_fc_layers = 8
#         head = 4
#         trsf_num_layer = 2
#         trsf_dropout = 0.353127
#         trsf_hidden = 3
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 26.3731
# Function value obtained: -0.4724
# Current minimum: -0.8387
# Iteration No: 11 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.494, Auc 0.486, 160.6 samples/s cuda.
# On validation set: Loss 0.693, Accuracy 0.544, Auc 0.888.
# On test set: Loss 0.694, Accuracy 0.588, Auc 0.865.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 6
#         lstm_dropout = 0.481772
#         num_lstm_hiddens = 64
#         lr = 0.002157
#         patience = 7
#         num_fc_layers = 7
#         head = 2
#         trsf_num_layer = 6
#         trsf_dropout = 0.500000
#         trsf_hidden = 4
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 177.0852
# Function value obtained: -0.8631
# Current minimum: -0.8631
# Iteration No: 12 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.642, Accuracy 0.631, Auc 0.676, 233.4 samples/s cuda.
# On validation set: Loss 0.625, Accuracy 0.675, Auc 0.827.
# On test set: Loss 0.594, Accuracy 0.725, Auc 0.876.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.100000
#         num_lstm_hiddens = 64
#         lr = 0.001000
#         patience = 1
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 10
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 33.0990
# Function value obtained: -0.7964
# Current minimum: -0.8631
# Iteration No: 13 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.484, Auc 0.586, 207.0 samples/s cuda.
# On validation set: Loss 0.695, Accuracy 0.469, Auc 0.771.
# On test set: Loss 0.696, Accuracy 0.525, Auc 0.802.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.100000
#         num_lstm_hiddens = 64
#         lr = 0.001000
#         patience = 10
#         num_fc_layers = 10
#         head = 2
#         trsf_num_layer = 4
#         trsf_dropout = 0.500000
#         trsf_hidden = 1
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 317.0718
# Function value obtained: -0.7729
# Current minimum: -0.8631
# Iteration No: 14 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.634, Accuracy 0.667, Auc 0.770, 67.3 samples/s cuda.
# On validation set: Loss 0.666, Accuracy 0.619, Auc 0.809.
# On test set: Loss 0.655, Accuracy 0.594, Auc 0.826.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_var_phred_score', 'fraction_MapQmin30', 'normalized_depth', 'gnomad_maxAF', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'germline_reads', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'cosmic_lung_count', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 4
#         lstm_dropout = 0.357423
#         num_lstm_hiddens = 64
#         lr = 0.002347
#         patience = 1
#         num_fc_layers = 1
#         head = 4
#         trsf_num_layer = 10
#         trsf_dropout = 0.100000
#         trsf_hidden = 10
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 48.4468
# Function value obtained: -0.7606
# Current minimum: -0.8631
# Iteration No: 15 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.708, Accuracy 0.487, Auc 0.473, 174.2 samples/s cuda.
# On validation set: Loss 0.680, Accuracy 0.569, Auc 0.837.
# On test set: Loss 0.673, Accuracy 0.600, Auc 0.856.
# Current parameters:
#         snv_selected = ['Chr', 'variant_count_norm', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma cfDNA concentration (ng/mL)', 'snv_valid_len', 'label']
#         num_lstm_layers = 2
#         lstm_dropout = 0.411919
#         num_lstm_hiddens = 64
#         lr = 0.003631
#         patience = 1
#         num_fc_layers = 4
#         head = 10
#         trsf_num_layer = 3
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 17.3683
# Function value obtained: -0.8011
# Current minimum: -0.8631
# Iteration No: 16 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.694, Accuracy 0.504, Auc 0.474, 44.5 samples/s cuda.
# On validation set: Loss 0.692, Accuracy 0.487, Auc 0.500.
# On test set: Loss 0.700, Accuracy 0.463, Auc 0.500.
# Current parameters:
#         snv_selected = ['germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'germline_reads', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Sex', 'Smoker', 'label']
#         num_lstm_layers = 8
#         lstm_dropout = 0.100000
#         num_lstm_hiddens = 64
#         lr = 0.003544
#         patience = 8
#         num_fc_layers = 10
#         head = 6
#         trsf_num_layer = 9
#         trsf_dropout = 0.313941
#         trsf_hidden = 2
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 1005.2713
# Function value obtained: -0.4751
# Current minimum: -0.8631
# Iteration No: 17 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.603, Accuracy 0.713, Auc 0.743, 144.0 samples/s cuda.
# On validation set: Loss 0.643, Accuracy 0.569, Auc 0.840.
# On test set: Loss 0.609, Accuracy 0.619, Auc 0.853.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 3
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.001321
#         patience = 6
#         num_fc_layers = 3
#         head = 8
#         trsf_num_layer = 1
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 124.3255
# Function value obtained: -0.8334
# Current minimum: -0.8631
# Iteration No: 18 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.699, Accuracy 0.494, Auc 0.546, 110.7 samples/s cuda.
# On validation set: Loss 0.683, Accuracy 0.556, Auc 0.776.
# On test set: Loss 0.673, Accuracy 0.600, Auc 0.793.
# Current parameters:
#         snv_selected = ['Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_num_non_ref_bases', 'normalized_depth', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.132424
#         num_lstm_hiddens = 64
#         lr = 0.001000
#         patience = 1
#         num_fc_layers = 4
#         head = 2
#         trsf_num_layer = 10
#         trsf_dropout = 0.500000
#         trsf_hidden = 2
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 23.0163
# Function value obtained: -0.7678
# Current minimum: -0.8631
# Iteration No: 19 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.663, Accuracy 0.645, Auc 0.701, 172.0 samples/s cuda.
# On validation set: Loss 0.667, Accuracy 0.619, Auc 0.795.
# On test set: Loss 0.654, Accuracy 0.706, Auc 0.859.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_norm_varpos', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.100000
#         num_lstm_hiddens = 64
#         lr = 0.002392
#         patience = 1
#         num_fc_layers = 5
#         head = 4
#         trsf_num_layer = 6
#         trsf_dropout = 0.403505
#         trsf_hidden = 10
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 60.2983
# Function value obtained: -0.7697
# Current minimum: -0.8631
# Iteration No: 20 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.614, Accuracy 0.674, Auc 0.739, 155.9 samples/s cuda.
# On validation set: Loss 0.638, Accuracy 0.606, Auc 0.839.
# On test set: Loss 0.632, Accuracy 0.631, Auc 0.840.
# Current parameters:
#         snv_selected = ['Variant.type', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 2
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.001000
#         patience = 1
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 4
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 39.1480
# Function value obtained: -0.7820
# Current minimum: -0.8631
# Iteration No: 21 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.693, Accuracy 0.552, Auc 0.523, 146.3 samples/s cuda.
# On validation set: Loss 0.672, Accuracy 0.650, Auc 0.736.
# On test set: Loss 0.663, Accuracy 0.713, Auc 0.812.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_norm_varpos', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'germline_reads', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Plasma volume used', 'Plasma DNA input (ng)', 'label']
#         num_lstm_layers = 3
#         lstm_dropout = 0.305335
#         num_lstm_hiddens = 64
#         lr = 0.001000
#         patience = 2
#         num_fc_layers = 6
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 169.4555
# Function value obtained: -0.7345
# Current minimum: -0.8631
# Iteration No: 22 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.696, Accuracy 0.488, Auc 0.497, 35.8 samples/s cuda.
# On validation set: Loss 0.695, Accuracy 0.469, Auc 0.851.
# On test set: Loss 0.702, Accuracy 0.400, Auc 0.845.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.002018
#         patience = 10
#         num_fc_layers = 5
#         head = 2
#         trsf_num_layer = 10
#         trsf_dropout = 0.354260
#         trsf_hidden = 1
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 258.7127
# Function value obtained: -0.8350
# Current minimum: -0.8631
# Iteration No: 23 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.495, Auc 0.509, 96.2 samples/s cuda.
# On validation set: Loss 0.690, Accuracy 0.519, Auc 0.831.
# On test set: Loss 0.681, Accuracy 0.537, Auc 0.791.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 4
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.002123
#         patience = 5
#         num_fc_layers = 5
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 128.6904
# Function value obtained: -0.8011
# Current minimum: -0.8631
# Iteration No: 24 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.549, Accuracy 0.798, Auc 0.793, 45.2 samples/s cuda.
# On validation set: Loss 0.658, Accuracy 0.637, Auc 0.789.
# On test set: Loss 0.543, Accuracy 0.769, Auc 0.874.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.001571
#         patience = 10
#         num_fc_layers = 3
#         head = 10
#         trsf_num_layer = 4
#         trsf_dropout = 0.100000
#         trsf_hidden = 1
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 578.3255
# Function value obtained: -0.8183
# Current minimum: -0.8631
# Iteration No: 25 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.705, Accuracy 0.515, Auc 0.494, 49.9 samples/s cuda.
# On validation set: Loss 0.674, Accuracy 0.631, Auc 0.562.
# On test set: Loss 0.666, Accuracy 0.681, Auc 0.572.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Plasma volume used', 'Plasma DNA input (ng)', 'label']
#         num_lstm_layers = 7
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.001392
#         patience = 1
#         num_fc_layers = 4
#         head = 2
#         trsf_num_layer = 6
#         trsf_dropout = 0.500000
#         trsf_hidden = 10
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 105.2917
# Function value obtained: -0.5257
# Current minimum: -0.8631
# Iteration No: 26 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.586, Accuracy 0.716, Auc 0.805, 139.9 samples/s cuda.
# On validation set: Loss 0.613, Accuracy 0.656, Auc 0.804.
# On test set: Loss 0.588, Accuracy 0.713, Auc 0.849.
# Current parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'duplex_reads', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'cosmic_total_count', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Plasma volume used', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.318311
#         num_lstm_hiddens = 64
#         lr = 0.002370
#         patience = 1
#         num_fc_layers = 1
#         head = 6
#         trsf_num_layer = 6
#         trsf_dropout = 0.144581
#         trsf_hidden = 7
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 32.2823
# Function value obtained: -0.7928
# Current minimum: -0.8631
# Iteration No: 27 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.411, Accuracy 0.913, Auc 0.949, 144.8 samples/s cuda.
# On validation set: Loss 0.572, Accuracy 0.731, Auc 0.790.
# On test set: Loss 0.472, Accuracy 0.838, Auc 0.915.
# Current parameters:
#         snv_selected = ['Variant.type', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'germline_depth_at_position', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['Age (years)', 'Sex', 'Smoker', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.188149
#         num_lstm_hiddens = 64
#         lr = 0.001553
#         patience = 10
#         num_fc_layers = 2
#         head = 10
#         trsf_num_layer = 6
#         trsf_dropout = 0.474175
#         trsf_hidden = 9
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 163.0694
# Function value obtained: -0.8191
# Current minimum: -0.8631
# Iteration No: 28 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.437, Accuracy 0.890, Auc 0.939, 121.8 samples/s cuda.
# On validation set: Loss 0.570, Accuracy 0.725, Auc 0.811.
# On test set: Loss 0.495, Accuracy 0.787, Auc 0.898.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'pass_split_1yes', 'gnomad_maxAF', 'base_change_transition', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'cosmic_lung_count', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.114568
#         num_lstm_hiddens = 64
#         lr = 0.003131
#         patience = 8
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 9
#         trsf_dropout = 0.100000
#         trsf_hidden = 4
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 115.5066
# Function value obtained: -0.8441
# Current minimum: -0.8631
# Iteration No: 29 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.695, Accuracy 0.481, Auc 0.513, 42.1 samples/s cuda.
# On validation set: Loss 0.689, Accuracy 0.581, Auc 0.736.
# On test set: Loss 0.685, Accuracy 0.650, Auc 0.738.
# Current parameters:
#         snv_selected = ['Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'pass_split_1yes', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'variant_norm_bc_fam_size', 'normalized_depth', 'gnomad_maxAF', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'Age (years)', 'Plasma volume used', 'Plasma DNA input (ng)', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.126277
#         num_lstm_hiddens = 64
#         lr = 0.002141
#         patience = 6
#         num_fc_layers = 7
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.428495
#         trsf_hidden = 9
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 502.0636
# Function value obtained: -0.7087
# Current minimum: -0.8631
# Iteration No: 30 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.689, Accuracy 0.558, Auc 0.555, 195.6 samples/s cuda.
# On validation set: Loss 0.689, Accuracy 0.556, Auc 0.777.
# On test set: Loss 0.684, Accuracy 0.606, Auc 0.868.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.210665
#         num_lstm_hiddens = 64
#         lr = 0.003090
#         patience = 4
#         num_fc_layers = 7
#         head = 6
#         trsf_num_layer = 3
#         trsf_dropout = 0.156238
#         trsf_hidden = 10
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 172.2185
# Function value obtained: -0.7996
# Current minimum: -0.8631
# Iteration No: 31 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.614, Accuracy 0.704, Auc 0.689, 47.2 samples/s cuda.
# On validation set: Loss 0.585, Accuracy 0.731, Auc 0.717.
# On test set: Loss 0.571, Accuracy 0.738, Auc 0.706.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'cfdnabg_Bayesian_pval', 'germline_reads', 'germline_depth_at_position', 'cosmic_total_count', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 6
#         lstm_dropout = 0.223817
#         num_lstm_hiddens = 64
#         lr = 0.002589
#         patience = 10
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 10
#         trsf_dropout = 0.100000
#         trsf_hidden = 1
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 244.1430
# Function value obtained: -0.6773
# Current minimum: -0.8631
# Iteration No: 32 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.402, Accuracy 0.931, Auc 0.965, 152.1 samples/s cuda.
# On validation set: Loss 0.562, Accuracy 0.750, Auc 0.836.
# On test set: Loss 0.455, Accuracy 0.869, Auc 0.931.
# ********************
# Best parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.500000
#         num_lstm_hiddens = 64
#         lr = 0.003168
#         patience = 5
#         num_fc_layers = 1
#         head = 4
#         trsf_num_layer = 6
#         trsf_dropout = 0.281653
#         trsf_hidden = 10
# ********************
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 90.4929
# Function value obtained: -0.8697
# Current minimum: -0.8697
# Iteration No: 33 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.699, Accuracy 0.476, Auc 0.460, 46.6 samples/s cuda.
# On validation set: Loss 0.691, Accuracy 0.512, Auc 0.723.
# On test set: Loss 0.686, Accuracy 0.537, Auc 0.755.
# Current parameters:
# ...
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.100000
#         num_lstm_hiddens = 512
#         lr = 0.008009
#         patience = 5
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.294501
#         trsf_hidden = 10
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 88.5102
# Function value obtained: -0.5574
# Current minimum: -0.8870
# Iteration No: 91 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.536, Accuracy 0.778, Auc 0.791, 370.9 samples/s cuda.
# On validation set: Loss 0.612, Accuracy 0.650, Auc 0.868.
# On test set: Loss 0.574, Accuracy 0.706, Auc 0.911.
# Current parameters:
#         snv_selected = ['Gene', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'mean_bc_family_size', 'mean_norm_varpos', 'fraction_MapQmin30', 'gnomad_maxAF', 'LUNG_driver', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.285591
#         num_lstm_hiddens = 128
#         lr = 0.002568
#         patience = 6
#         num_fc_layers = 5
#         head = 6
#         trsf_num_layer = 3
#         trsf_dropout = 0.232560
#         trsf_hidden = 10
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 53.0920
# Function value obtained: -0.8786
# Current minimum: -0.8870
# Iteration No: 92 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.697, Accuracy 0.502, Auc 0.480, 290.4 samples/s cuda.
# On validation set: Loss 0.689, Accuracy 0.569, Auc 0.726.
# On test set: Loss 0.681, Accuracy 0.650, Auc 0.751.
# Current parameters:
#         snv_selected = ['Gene', 'variant_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_norm_varpos', 'variant_norm_bc_fam_size', 'normalized_depth', 'size_selected_adjustment', 'LUNG_driver', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'tumor_adjudicated', 'has_matched_tumor', 'intersect_unpadded_selector', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.457127
#         num_lstm_hiddens = 64
#         lr = 0.002127
#         patience = 5
#         num_fc_layers = 8
#         head = 6
#         trsf_num_layer = 5
#         trsf_dropout = 0.429060
#         trsf_hidden = 1
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 141.3261
# Function value obtained: -0.7287
# Current minimum: -0.8870
# Iteration No: 93 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.545, Accuracy 0.743, Auc 0.843, 530.7 samples/s cuda.
# On validation set: Loss 0.518, Accuracy 0.781, Auc 0.893.
# On test set: Loss 0.547, Accuracy 0.738, Auc 0.865.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'normalized_depth', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_gistic', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.124673
#         num_lstm_hiddens = 128
#         lr = 0.001591
#         patience = 2
#         num_fc_layers = 1
#         head = 2
#         trsf_num_layer = 1
#         trsf_dropout = 0.107362
#         trsf_hidden = 10
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 16.6974
# Function value obtained: -0.8381
# Current minimum: -0.8870
# Iteration No: 94 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.437, Accuracy 0.880, Auc 0.913, 589.0 samples/s cuda.
# On validation set: Loss 0.597, Accuracy 0.700, Auc 0.751.
# On test set: Loss 0.510, Accuracy 0.800, Auc 0.826.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'size_selected_adjustment', 'LUNG_driver', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.289779
#         num_lstm_hiddens = 512
#         lr = 0.001080
#         patience = 10
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.370520
#         trsf_hidden = 10
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 84.2948
# Function value obtained: -0.7771
# Current minimum: -0.8870
# Iteration No: 95 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.507, Accuracy 0.794, Auc 0.896, 555.0 samples/s cuda.
# On validation set: Loss 0.573, Accuracy 0.725, Auc 0.863.
# On test set: Loss 0.547, Accuracy 0.744, Auc 0.877.
# Current parameters:
#         snv_selected = ['Variant.type', 'Gene', 'Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.488975
#         num_lstm_hiddens = 128
#         lr = 0.002849
#         patience = 3
#         num_fc_layers = 1
#         head = 6
#         trsf_num_layer = 1
#         trsf_dropout = 0.416999
#         trsf_hidden = 10
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 19.2973
# Function value obtained: -0.8587
# Current minimum: -0.8870
# Iteration No: 96 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.535, Accuracy 0.773, Auc 0.859, 581.0 samples/s cuda.
# On validation set: Loss 0.601, Accuracy 0.669, Auc 0.817.
# On test set: Loss 0.579, Accuracy 0.694, Auc 0.858.
# Current parameters:
#         snv_selected = ['ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.100000
#         num_lstm_hiddens = 128
#         lr = 0.002636
#         patience = 2
#         num_fc_layers = 1
#         head = 6
#         trsf_num_layer = 1
#         trsf_dropout = 0.214590
#         trsf_hidden = 10
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 14.6261
# Function value obtained: -0.8271
# Current minimum: -0.8870
# Iteration No: 97 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.648, Accuracy 0.648, Auc 0.816, 108.4 samples/s cuda.
# On validation set: Loss 0.637, Accuracy 0.662, Auc 0.853.
# On test set: Loss 0.604, Accuracy 0.700, Auc 0.839.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'LUNG_driver', 'pass_basic_QC_nonsynon_lungdriver', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.242895
#         num_lstm_hiddens = 512
#         lr = 0.001011
#         patience = 3
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.106380
#         trsf_hidden = 10
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 91.3036
# Function value obtained: -0.8328
# Current minimum: -0.8870
# Iteration No: 98 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.481, Accuracy 0.836, Auc 0.888, 611.4 samples/s cuda.
# On validation set: Loss 0.536, Accuracy 0.762, Auc 0.853.
# On test set: Loss 0.499, Accuracy 0.812, Auc 0.879.
# Current parameters:
#         snv_selected = ['germline_NumNonZeroMeanAF_Pval', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'normalized_depth', 'gnomad_maxAF', 'LUNG_driver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'sum_log10_frag_size_enrich_score', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Age (years)', 'Sex', 'Smoker', 'Plasma volume used', 'Plasma cfDNA concentration (ng/mL)', 'Plasma DNA input (ng)', 'snv_valid_len', 'label']
#         num_lstm_layers = 1
#         lstm_dropout = 0.319513
#         num_lstm_hiddens = 256
#         lr = 0.001388
#         patience = 10
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.132703
#         trsf_hidden = 1
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 37.1407
# Function value obtained: -0.8111
# Current minimum: -0.8870
# Iteration No: 99 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.553, Accuracy 0.739, Auc 0.824, 148.0 samples/s cuda.
# On validation set: Loss 0.549, Accuracy 0.731, Auc 0.852.
# On test set: Loss 0.511, Accuracy 0.781, Auc 0.870.
# Current parameters:
#         snv_selected = ['Variant.type', 'Chr', 'Position', 'Gene', 'Percent.mutant.allele', 'variant_count_norm', 'ontarget_shoulder_tile_mut_count_norm', 'pass_split_1yes', 'duplex_reads', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'mean_norm_varpos', 'mean_var_phred_score', 'mean_num_non_ref_bases', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver', 'germlinebg_Bayesian_pval', 'cfdnabg_Bayesian_pval', 'germline_reads', 'tumor_adjudicated', 'cosmic_total_count', 'has_matched_tumor', 'intersect_unpadded_selector', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
#         other_feature_selected = ['snv_valid_len', 'label']
#         num_lstm_layers = 10
#         lstm_dropout = 0.314576
#         num_lstm_hiddens = 256
#         lr = 0.003353
#         patience = 4
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.244079
#         trsf_hidden = 9
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 59.4191
# Function value obtained: -0.8480
# Current minimum: -0.8870
# Iteration No: 100 started. Searching for the next optimal point.
# --------------------
# One layer without smote without mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.525, Accuracy 0.788, Auc 0.834, 206.4 samples/s cuda.
# On validation set: Loss 0.606, Accuracy 0.700, Auc 0.796.
# On test set: Loss 0.560, Accuracy 0.744, Auc 0.856.
# Current parameters:
#         snv_selected = ['Percent.mutant.allele', 'ontarget_shoulder_tile_mut_count_norm', 'germline_NumNonZeroMeanAF_Pval', 'mean_bc_family_size', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_norm_varpos', 'mean_var_phred_score', 'fraction_MapQmin30', 'normalized_depth', 'gnomad_maxAF', 'base_change_transition', 'size_selected_adjustment', 'pass_basic_QC_nonsynon_lungdriver_hotspot', 'sum_log10_frag_size_enrich_score', 'germline_reads', 'germline_depth_at_position', 'BaseConversion', 'patientID']
#         other_feature_selected = ['cnv_Count_5mb', 'cnv_Count_gistic', 'Plasma volume used', 'snv_valid_len', 'label']
#         num_lstm_layers = 6
#         lstm_dropout = 0.382896
#         num_lstm_hiddens = 64
#         lr = 0.001000
#         patience = 10
#         num_fc_layers = 1
#         head = 10
#         trsf_num_layer = 1
#         trsf_dropout = 0.100000
#         trsf_hidden = 2
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 101.2038
# Function value obtained: -0.7988
# Current minimum: -0.8870
# Best parameters:
# snv_selected = ['Position', 'Gene', 'pass_split_1yes', 'duplex_reads', 'watsoncrickfisher.p', 'mean_total_bc_errors_corrected', 'mean_num_non_ref_bases', 'fraction_MapQmin30', 'base_change_transition', 'pass_basic_QC_nonsynon_lungdriver', 'sum_log10_frag_size_enrich_score', 'tumor_adjudicated', 'has_matched_tumor', 'cosmic_lung_count', 'blacklist3tumorsupressor', 'BaseConversion', 'patientID']
# other_feature_selected = ['snv_valid_len', 'label']
# num_lstm_layers = 1
# lstm_dropout = 0.248696
# num_lstm_hiddens = 64
# lr = 0.004359
# patience = 10
# num_fc_layers = 2
# head = 6
# trsf_num_layer = 3
# trsf_dropout = 0.269934
# trsf_hidden = 3

# %%
len(snv_selected)
# Out:
# 17

# %%
# ---------------------------------------------------#   
#    Parameter Tuning with Bayesian optimization    #
#--------------------------------------------------# 
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

seed = 1105

num_outer_split = 5
num_output_nodes, num_epochs = 2, 100
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
num_lstm_layers, lstm_dropout, num_lstm_hiddens, lr, patience = masked_gp.x[5], masked_gp.x[6], masked_gp.x[7], masked_gp.x[8], masked_gp.x[9]
num_fc_layers, head, trsf_num_layer, trsf_dropout, trsf_hidden = masked_gp.x[10], masked_gp.x[11], masked_gp.x[12], masked_gp.x[13], masked_gp.x[14]

new_train_snv = deepcopy(train_snv[snv_selected])
new_train_x = deepcopy(train_x[other_feature_selected])
new_train_x = NewGroupAndExtractSNV(new_train_x, new_train_snv, num_steps)

new_test_snv = deepcopy(test_snv[snv_selected])
new_test_x = deepcopy(test_x[other_feature_selected])
new_test_x = NewGroupAndExtractSNV(new_test_x, new_test_snv, num_steps)

num_inputs_lstm = new_train_x.iloc[0]['snv'].shape[1]
num_feature_not_snv = len(other_feature_selected)-1

shape = new_train_x.iloc[0]['snv'].shape

num_repeat = 100
frac_val = 0.25
train_all = []
val_all = []
test_all = []
for i in range(num_repeat):
    seed = seed + i
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
       
    sub_train_index, sub_val_index = next(StratifiedShuffleSplit(n_splits=1,test_size=frac_val).split(new_train_x,new_train_x['label']))

    #---  Seperate traing set, validation set and test set ---#
    sub_train = Resampler(new_train_x.iloc[sub_train_index][:], new_train_x.iloc[sub_train_index]['label'])
    train_iter = BatchDataGeneration(sub_train, batch_size, shuffle=True)
    val_iter = BatchDataGeneration(new_train_x.iloc[sub_val_index][:], batch_size, shuffle=True)
    test_iter = BatchDataGeneration(new_test_x, batch_size, shuffle=True)
    
    #-----  Instantiate model -----#
    
    model = AutoCancer(num_inputs_lstm, num_lstm_hiddens, num_lstm_layers, lstm_bidirectional, lstm_dropout,
                                 num_feature_not_snv, num_output_nodes, num_fc_layers, device, head, trsf_num_layer,
                                 trsf_dropout, trsf_hidden, shape)
    model = model.to(device)
    model.apply(init_weights)
    
    #-----  Loss -----#
    loss = nn.CrossEntropyLoss(reduction="none")
    loss = loss.to(device)

    #--- Define optimizer ---#
    optimizer = torch.optim.Adam(model.parameters(), lr)

    #-----  Instantiate EarlyStopping -----#
    early_stopping = EarlyStopping(patience, verbose=False)

    train_loss, train_acc, train_auc, train_speed, val_loss, val_acc, val_auc = train_evaluate(
        model, train_iter, val_iter, loss, optimizer, early_stopping, num_epochs, device)

    test_loss, test_acc, test_auc = evaluate(model, test_iter, loss, device)

    train_all.append([train_loss, train_acc, train_auc, train_speed])
    val_all.append([val_loss, val_acc, val_auc])
    test_all.append([test_loss, test_acc, test_auc])
    print('-'*20)
    print('num of repeat:', i)
    print('-'*20)
    print(f'On training set: Loss {train_loss:.3f}, Accuracy {train_acc:.3f}, Auc {train_auc:.3f}, {train_speed:.1f} samples/s {str(device)}.')
    print(f'On validation set: Loss {val_loss:.3f}, Accuracy {val_acc:.3f}, Auc {val_auc:.3f}.')
    print(f'On test set: Loss {test_loss:.3f}, Accuracy {test_acc:.3f}, Auc {test_auc:.3f}.')


train_all = np.array(train_all)
val_all = np.array(val_all)
test_all = np.array(test_all)

train_loss, train_acc, train_auc, train_speed = train_all[:,0], train_all[:,1], train_all[:,2], train_all[:,3]
val_loss, val_acc, val_auc = val_all[:,0], val_all[:,1], val_all[:,2]
test_loss, test_acc, test_auc = test_all[:,0], test_all[:,1], test_all[:,2]    
print('-'*20)
print('One layer without smote with mask with early stopping under k-fold cv best model:')
print('-'*20)
print(f'On training set: Loss {train_loss.mean():.3f}, Accuracy {train_acc.mean():.3f}, Auc {train_auc.mean():.3f}, {train_speed.mean():.1f} samples/s {str(device)}.')
print(f'On validation set: Loss {val_loss.mean():.3f}, Accuracy {val_acc.mean():.3f}, Auc {val_auc.mean():.3f}.')
print(f'On test set: Loss {test_loss.mean():.3f}, Accuracy {test_acc.mean():.3f}, Auc {test_auc.mean():.3f}.')

#-----  Save performance -----#
df = (('train_loss', 'train_acc', 'train_auc', 'train_speed', 'val_loss', 'val_acc', 'val_auc', 'test_loss', 'test_acc', 'test_auc'),  
      (train_loss, train_acc, train_auc, train_speed, val_loss, val_acc, val_auc, test_loss, test_acc, test_auc)  
      )
df = pd.DataFrame(df)
t = time.localtime()
file_name = 'AutoCancer'+str(t.tm_year)+'-'+str(t.tm_mon)+'-'+str(t.tm_mday)+'-'+str(t.tm_hour)+'-'+str(t.tm_min)+'.xlsx' #(t.tm_year)
df.to_excel(file_name,index = False)
# Out:
# --------------------
# num of repeat: 0
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.985, 419.4 samples/s cuda.
# On validation set: Loss 0.479, Accuracy 0.850, Auc 0.916.
# On test set: Loss 0.568, Accuracy 0.734, Auc 0.790.
# --------------------
# num of repeat: 1
# --------------------
# On training set: Loss 0.343, Accuracy 0.974, Auc 0.982, 414.9 samples/s cuda.
# On validation set: Loss 0.474, Accuracy 0.825, Auc 0.920.
# On test set: Loss 0.597, Accuracy 0.702, Auc 0.725.
# --------------------
# num of repeat: 2
# --------------------
# On training set: Loss 0.353, Accuracy 0.962, Auc 0.979, 401.1 samples/s cuda.
# On validation set: Loss 0.533, Accuracy 0.775, Auc 0.852.
# On test set: Loss 0.573, Accuracy 0.734, Auc 0.774.
# --------------------
# num of repeat: 3
# --------------------
# On training set: Loss 0.358, Accuracy 0.962, Auc 0.994, 396.0 samples/s cuda.
# On validation set: Loss 0.446, Accuracy 0.850, Auc 0.931.
# On test set: Loss 0.559, Accuracy 0.734, Auc 0.751.
# --------------------
# num of repeat: 4
# --------------------
# On training set: Loss 0.358, Accuracy 0.955, Auc 0.983, 402.1 samples/s cuda.
# On validation set: Loss 0.541, Accuracy 0.750, Auc 0.867.
# On test set: Loss 0.593, Accuracy 0.734, Auc 0.750.
# --------------------
# num of repeat: 5
# --------------------
# On training set: Loss 0.352, Accuracy 0.968, Auc 0.968, 382.5 samples/s cuda.
# On validation set: Loss 0.522, Accuracy 0.800, Auc 0.842.
# On test set: Loss 0.604, Accuracy 0.702, Auc 0.753.
# --------------------
# num of repeat: 6
# --------------------
# On training set: Loss 0.349, Accuracy 0.974, Auc 0.976, 417.1 samples/s cuda.
# On validation set: Loss 0.573, Accuracy 0.725, Auc 0.846.
# On test set: Loss 0.583, Accuracy 0.702, Auc 0.760.
# --------------------
# num of repeat: 7
# --------------------
# On training set: Loss 0.355, Accuracy 0.968, Auc 0.982, 419.4 samples/s cuda.
# On validation set: Loss 0.474, Accuracy 0.825, Auc 0.904.
# On test set: Loss 0.613, Accuracy 0.702, Auc 0.758.
# --------------------
# num of repeat: 8
# --------------------
# On training set: Loss 0.359, Accuracy 0.955, Auc 0.973, 416.0 samples/s cuda.
# On validation set: Loss 0.497, Accuracy 0.800, Auc 0.871.
# On test set: Loss 0.577, Accuracy 0.713, Auc 0.782.
# --------------------
# num of repeat: 9
# --------------------
# On training set: Loss 0.433, Accuracy 0.885, Auc 0.939, 409.5 samples/s cuda.
# On validation set: Loss 0.600, Accuracy 0.700, Auc 0.820.
# On test set: Loss 0.633, Accuracy 0.660, Auc 0.762.
# --------------------
# num of repeat: 10
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.993, 427.4 samples/s cuda.
# On validation set: Loss 0.456, Accuracy 0.850, Auc 0.929.
# On test set: Loss 0.596, Accuracy 0.702, Auc 0.758.
# --------------------
# num of repeat: 11
# --------------------
# On training set: Loss 0.354, Accuracy 0.968, Auc 0.971, 395.0 samples/s cuda.
# On validation set: Loss 0.542, Accuracy 0.750, Auc 0.852.
# On test set: Loss 0.609, Accuracy 0.681, Auc 0.760.
# --------------------
# num of repeat: 12
# --------------------
# On training set: Loss 0.352, Accuracy 0.962, Auc 0.985, 418.3 samples/s cuda.
# On validation set: Loss 0.467, Accuracy 0.850, Auc 0.923.
# On test set: Loss 0.594, Accuracy 0.702, Auc 0.741.
# --------------------
# num of repeat: 13
# --------------------
# On training set: Loss 0.366, Accuracy 0.949, Auc 0.972, 409.5 samples/s cuda.
# On validation set: Loss 0.619, Accuracy 0.600, Auc 0.761.
# On test set: Loss 0.608, Accuracy 0.702, Auc 0.740.
# --------------------
# num of repeat: 14
# --------------------
# On training set: Loss 0.352, Accuracy 0.962, Auc 0.984, 408.4 samples/s cuda.
# On validation set: Loss 0.422, Accuracy 0.900, Auc 0.931.
# On test set: Loss 0.582, Accuracy 0.723, Auc 0.804.
# --------------------
# num of repeat: 15
# --------------------
# On training set: Loss 0.372, Accuracy 0.955, Auc 0.968, 388.2 samples/s cuda.
# On validation set: Loss 0.522, Accuracy 0.800, Auc 0.852.
# On test set: Loss 0.608, Accuracy 0.702, Auc 0.738.
# --------------------
# num of repeat: 16
# --------------------
# On training set: Loss 0.342, Accuracy 0.974, Auc 0.990, 413.8 samples/s cuda.
# On validation set: Loss 0.484, Accuracy 0.800, Auc 0.904.
# On test set: Loss 0.584, Accuracy 0.713, Auc 0.755.
# --------------------
# num of repeat: 17
# --------------------
# On training set: Loss 0.354, Accuracy 0.962, Auc 0.984, 419.4 samples/s cuda.
# On validation set: Loss 0.457, Accuracy 0.875, Auc 0.934.
# On test set: Loss 0.603, Accuracy 0.691, Auc 0.754.
# --------------------
# num of repeat: 18
# --------------------
# On training set: Loss 0.341, Accuracy 0.974, Auc 0.984, 417.1 samples/s cuda.
# On validation set: Loss 0.613, Accuracy 0.675, Auc 0.786.
# On test set: Loss 0.620, Accuracy 0.670, Auc 0.771.
# --------------------
# num of repeat: 19
# --------------------
# On training set: Loss 0.425, Accuracy 0.891, Auc 0.937, 410.6 samples/s cuda.
# On validation set: Loss 0.593, Accuracy 0.700, Auc 0.810.
# On test set: Loss 0.610, Accuracy 0.681, Auc 0.745.
# --------------------
# num of repeat: 20
# --------------------
# On training set: Loss 0.359, Accuracy 0.955, Auc 0.982, 400.1 samples/s cuda.
# On validation set: Loss 0.499, Accuracy 0.800, Auc 0.856.
# On test set: Loss 0.563, Accuracy 0.723, Auc 0.780.
# --------------------
# num of repeat: 21
# --------------------
# On training set: Loss 0.360, Accuracy 0.955, Auc 0.981, 401.1 samples/s cuda.
# On validation set: Loss 0.482, Accuracy 0.800, Auc 0.918.
# On test set: Loss 0.585, Accuracy 0.723, Auc 0.772.
# --------------------
# num of repeat: 22
# --------------------
# On training set: Loss 0.333, Accuracy 0.981, Auc 0.990, 405.2 samples/s cuda.
# On validation set: Loss 0.479, Accuracy 0.850, Auc 0.867.
# On test set: Loss 0.617, Accuracy 0.681, Auc 0.750.
# --------------------
# num of repeat: 23
# --------------------
# On training set: Loss 0.353, Accuracy 0.962, Auc 0.992, 413.8 samples/s cuda.
# On validation set: Loss 0.526, Accuracy 0.775, Auc 0.940.
# On test set: Loss 0.579, Accuracy 0.734, Auc 0.772.
# --------------------
# num of repeat: 24
# --------------------
# On training set: Loss 0.351, Accuracy 0.968, Auc 0.980, 402.1 samples/s cuda.
# On validation set: Loss 0.558, Accuracy 0.750, Auc 0.846.
# On test set: Loss 0.592, Accuracy 0.713, Auc 0.766.
# --------------------
# num of repeat: 25
# --------------------
# On training set: Loss 0.350, Accuracy 0.968, Auc 0.975, 418.2 samples/s cuda.
# On validation set: Loss 0.485, Accuracy 0.825, Auc 0.886.
# On test set: Loss 0.575, Accuracy 0.713, Auc 0.780.
# --------------------
# num of repeat: 26
# --------------------
# On training set: Loss 0.344, Accuracy 0.974, Auc 0.977, 406.3 samples/s cuda.
# On validation set: Loss 0.592, Accuracy 0.675, Auc 0.758.
# On test set: Loss 0.564, Accuracy 0.755, Auc 0.745.
# --------------------
# num of repeat: 27
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.983, 421.6 samples/s cuda.
# On validation set: Loss 0.521, Accuracy 0.750, Auc 0.861.
# On test set: Loss 0.590, Accuracy 0.702, Auc 0.751.
# --------------------
# num of repeat: 28
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.991, 362.9 samples/s cuda.
# On validation set: Loss 0.571, Accuracy 0.725, Auc 0.824.
# On test set: Loss 0.547, Accuracy 0.755, Auc 0.820.
# --------------------
# num of repeat: 29
# --------------------
# On training set: Loss 0.414, Accuracy 0.917, Auc 0.967, 393.0 samples/s cuda.
# On validation set: Loss 0.542, Accuracy 0.725, Auc 0.876.
# On test set: Loss 0.598, Accuracy 0.691, Auc 0.791.
# --------------------
# num of repeat: 30
# --------------------
# On training set: Loss 0.347, Accuracy 0.974, Auc 0.983, 364.6 samples/s cuda.
# On validation set: Loss 0.585, Accuracy 0.725, Auc 0.812.
# On test set: Loss 0.616, Accuracy 0.670, Auc 0.737.
# --------------------
# num of repeat: 31
# --------------------
# On training set: Loss 0.341, Accuracy 0.974, Auc 0.993, 422.8 samples/s cuda.
# On validation set: Loss 0.639, Accuracy 0.650, Auc 0.786.
# On test set: Loss 0.553, Accuracy 0.745, Auc 0.784.
# --------------------
# num of repeat: 32
# --------------------
# On training set: Loss 0.337, Accuracy 0.981, Auc 0.982, 399.0 samples/s cuda.
# On validation set: Loss 0.594, Accuracy 0.675, Auc 0.832.
# On test set: Loss 0.566, Accuracy 0.734, Auc 0.780.
# --------------------
# num of repeat: 33
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.988, 414.9 samples/s cuda.
# On validation set: Loss 0.491, Accuracy 0.800, Auc 0.923.
# On test set: Loss 0.561, Accuracy 0.755, Auc 0.765.
# --------------------
# num of repeat: 34
# --------------------
# On training set: Loss 0.340, Accuracy 0.974, Auc 0.979, 405.2 samples/s cuda.
# On validation set: Loss 0.579, Accuracy 0.700, Auc 0.827.
# On test set: Loss 0.573, Accuracy 0.723, Auc 0.774.
# --------------------
# num of repeat: 35
# --------------------
# On training set: Loss 0.342, Accuracy 0.981, Auc 0.983, 414.9 samples/s cuda.
# On validation set: Loss 0.564, Accuracy 0.750, Auc 0.824.
# On test set: Loss 0.569, Accuracy 0.745, Auc 0.784.
# --------------------
# num of repeat: 36
# --------------------
# On training set: Loss 0.382, Accuracy 0.955, Auc 0.963, 412.7 samples/s cuda.
# On validation set: Loss 0.579, Accuracy 0.725, Auc 0.797.
# On test set: Loss 0.578, Accuracy 0.734, Auc 0.766.
# --------------------
# num of repeat: 37
# --------------------
# On training set: Loss 0.348, Accuracy 0.968, Auc 0.980, 378.8 samples/s cuda.
# On validation set: Loss 0.421, Accuracy 0.900, Auc 0.926.
# On test set: Loss 0.561, Accuracy 0.745, Auc 0.783.
# --------------------
# num of repeat: 38
# --------------------
# On training set: Loss 0.349, Accuracy 0.968, Auc 0.981, 366.3 samples/s cuda.
# On validation set: Loss 0.548, Accuracy 0.750, Auc 0.854.
# On test set: Loss 0.588, Accuracy 0.723, Auc 0.759.
# --------------------
# num of repeat: 39
# --------------------
# On training set: Loss 0.346, Accuracy 0.968, Auc 0.984, 404.2 samples/s cuda.
# On validation set: Loss 0.522, Accuracy 0.775, Auc 0.868.
# On test set: Loss 0.604, Accuracy 0.670, Auc 0.770.
# --------------------
# num of repeat: 40
# --------------------
# On training set: Loss 0.357, Accuracy 0.968, Auc 0.973, 373.3 samples/s cuda.
# On validation set: Loss 0.526, Accuracy 0.775, Auc 0.876.
# On test set: Loss 0.580, Accuracy 0.723, Auc 0.786.
# --------------------
# num of repeat: 41
# --------------------
# On training set: Loss 0.341, Accuracy 0.974, Auc 0.990, 413.8 samples/s cuda.
# On validation set: Loss 0.539, Accuracy 0.775, Auc 0.863.
# On test set: Loss 0.612, Accuracy 0.702, Auc 0.763.
# --------------------
# num of repeat: 42
# --------------------
# On training set: Loss 0.350, Accuracy 0.968, Auc 0.984, 371.6 samples/s cuda.
# On validation set: Loss 0.540, Accuracy 0.750, Auc 0.870.
# On test set: Loss 0.579, Accuracy 0.713, Auc 0.758.
# --------------------
# num of repeat: 43
# --------------------
# On training set: Loss 0.354, Accuracy 0.962, Auc 0.983, 407.4 samples/s cuda.
# On validation set: Loss 0.403, Accuracy 0.900, Auc 0.975.
# On test set: Loss 0.605, Accuracy 0.691, Auc 0.728.
# --------------------
# num of repeat: 44
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.978, 397.0 samples/s cuda.
# On validation set: Loss 0.520, Accuracy 0.775, Auc 0.875.
# On test set: Loss 0.600, Accuracy 0.691, Auc 0.795.
# --------------------
# num of repeat: 45
# --------------------
# On training set: Loss 0.348, Accuracy 0.968, Auc 0.982, 412.7 samples/s cuda.
# On validation set: Loss 0.537, Accuracy 0.725, Auc 0.843.
# On test set: Loss 0.600, Accuracy 0.691, Auc 0.749.
# --------------------
# num of repeat: 46
# --------------------
# On training set: Loss 0.353, Accuracy 0.962, Auc 0.981, 426.2 samples/s cuda.
# On validation set: Loss 0.405, Accuracy 0.900, Auc 0.962.
# On test set: Loss 0.581, Accuracy 0.734, Auc 0.770.
# --------------------
# num of repeat: 47
# --------------------
# On training set: Loss 0.350, Accuracy 0.968, Auc 0.986, 421.6 samples/s cuda.
# On validation set: Loss 0.476, Accuracy 0.825, Auc 0.922.
# On test set: Loss 0.568, Accuracy 0.734, Auc 0.792.
# --------------------
# num of repeat: 48
# --------------------
# On training set: Loss 0.341, Accuracy 0.981, Auc 0.992, 420.5 samples/s cuda.
# On validation set: Loss 0.567, Accuracy 0.700, Auc 0.783.
# On test set: Loss 0.597, Accuracy 0.702, Auc 0.761.
# --------------------
# num of repeat: 49
# --------------------
# On training set: Loss 0.367, Accuracy 0.949, Auc 0.963, 404.2 samples/s cuda.
# On validation set: Loss 0.536, Accuracy 0.750, Auc 0.846.
# On test set: Loss 0.602, Accuracy 0.702, Auc 0.741.
# --------------------
# num of repeat: 50
# --------------------
# On training set: Loss 0.362, Accuracy 0.962, Auc 0.970, 414.9 samples/s cuda.
# On validation set: Loss 0.505, Accuracy 0.775, Auc 0.909.
# On test set: Loss 0.570, Accuracy 0.745, Auc 0.783.
# --------------------
# num of repeat: 51
# --------------------
# On training set: Loss 0.341, Accuracy 0.974, Auc 0.978, 411.6 samples/s cuda.
# On validation set: Loss 0.532, Accuracy 0.750, Auc 0.863.
# On test set: Loss 0.588, Accuracy 0.713, Auc 0.762.
# --------------------
# num of repeat: 52
# --------------------
# On training set: Loss 0.352, Accuracy 0.968, Auc 0.976, 416.0 samples/s cuda.
# On validation set: Loss 0.505, Accuracy 0.825, Auc 0.857.
# On test set: Loss 0.568, Accuracy 0.734, Auc 0.759.
# --------------------
# num of repeat: 53
# --------------------
# On training set: Loss 0.353, Accuracy 0.968, Auc 0.982, 411.6 samples/s cuda.
# On validation set: Loss 0.522, Accuracy 0.800, Auc 0.879.
# On test set: Loss 0.604, Accuracy 0.681, Auc 0.783.
# --------------------
# num of repeat: 54
# --------------------
# On training set: Loss 0.348, Accuracy 0.968, Auc 0.988, 400.1 samples/s cuda.
# On validation set: Loss 0.536, Accuracy 0.750, Auc 0.793.
# On test set: Loss 0.588, Accuracy 0.723, Auc 0.773.
# --------------------
# num of repeat: 55
# --------------------
# On training set: Loss 0.331, Accuracy 0.987, Auc 0.994, 409.5 samples/s cuda.
# On validation set: Loss 0.530, Accuracy 0.775, Auc 0.827.
# On test set: Loss 0.576, Accuracy 0.734, Auc 0.745.
# --------------------
# num of repeat: 56
# --------------------
# On training set: Loss 0.354, Accuracy 0.962, Auc 0.982, 376.9 samples/s cuda.
# On validation set: Loss 0.511, Accuracy 0.800, Auc 0.871.
# On test set: Loss 0.600, Accuracy 0.702, Auc 0.736.
# --------------------
# num of repeat: 57
# --------------------
# On training set: Loss 0.336, Accuracy 0.981, Auc 0.987, 413.8 samples/s cuda.
# On validation set: Loss 0.616, Accuracy 0.650, Auc 0.790.
# On test set: Loss 0.594, Accuracy 0.702, Auc 0.795.
# --------------------
# num of repeat: 58
# --------------------
# On training set: Loss 0.340, Accuracy 0.981, Auc 0.989, 412.7 samples/s cuda.
# On validation set: Loss 0.592, Accuracy 0.675, Auc 0.787.
# On test set: Loss 0.572, Accuracy 0.745, Auc 0.756.
# --------------------
# num of repeat: 59
# --------------------
# On training set: Loss 0.359, Accuracy 0.955, Auc 0.983, 376.0 samples/s cuda.
# On validation set: Loss 0.528, Accuracy 0.775, Auc 0.879.
# On test set: Loss 0.566, Accuracy 0.755, Auc 0.763.
# --------------------
# num of repeat: 60
# --------------------
# On training set: Loss 0.368, Accuracy 0.955, Auc 0.971, 364.6 samples/s cuda.
# On validation set: Loss 0.531, Accuracy 0.800, Auc 0.838.
# On test set: Loss 0.587, Accuracy 0.723, Auc 0.761.
# --------------------
# num of repeat: 61
# --------------------
# On training set: Loss 0.343, Accuracy 0.974, Auc 0.982, 421.6 samples/s cuda.
# On validation set: Loss 0.446, Accuracy 0.850, Auc 0.923.
# On test set: Loss 0.574, Accuracy 0.734, Auc 0.741.
# --------------------
# num of repeat: 62
# --------------------
# On training set: Loss 0.346, Accuracy 0.968, Auc 0.979, 398.0 samples/s cuda.
# On validation set: Loss 0.573, Accuracy 0.700, Auc 0.827.
# On test set: Loss 0.586, Accuracy 0.734, Auc 0.756.
# --------------------
# num of repeat: 63
# --------------------
# On training set: Loss 0.365, Accuracy 0.949, Auc 0.970, 405.2 samples/s cuda.
# On validation set: Loss 0.559, Accuracy 0.750, Auc 0.799.
# On test set: Loss 0.592, Accuracy 0.713, Auc 0.782.
# --------------------
# num of repeat: 64
# --------------------
# On training set: Loss 0.346, Accuracy 0.968, Auc 0.993, 405.2 samples/s cuda.
# On validation set: Loss 0.439, Accuracy 0.850, Auc 0.929.
# On test set: Loss 0.603, Accuracy 0.681, Auc 0.755.
# --------------------
# num of repeat: 65
# --------------------
# On training set: Loss 0.340, Accuracy 0.974, Auc 0.988, 370.7 samples/s cuda.
# On validation set: Loss 0.523, Accuracy 0.800, Auc 0.865.
# On test set: Loss 0.581, Accuracy 0.723, Auc 0.774.
# --------------------
# num of repeat: 66
# --------------------
# On training set: Loss 0.356, Accuracy 0.962, Auc 0.986, 423.9 samples/s cuda.
# On validation set: Loss 0.549, Accuracy 0.750, Auc 0.860.
# On test set: Loss 0.582, Accuracy 0.713, Auc 0.765.
# --------------------
# num of repeat: 67
# --------------------
# On training set: Loss 0.361, Accuracy 0.955, Auc 0.980, 408.4 samples/s cuda.
# On validation set: Loss 0.589, Accuracy 0.700, Auc 0.777.
# On test set: Loss 0.574, Accuracy 0.734, Auc 0.754.
# --------------------
# num of repeat: 68
# --------------------
# On training set: Loss 0.352, Accuracy 0.962, Auc 0.974, 366.3 samples/s cuda.
# On validation set: Loss 0.511, Accuracy 0.800, Auc 0.848.
# On test set: Loss 0.581, Accuracy 0.723, Auc 0.769.
# --------------------
# num of repeat: 69
# --------------------
# On training set: Loss 0.353, Accuracy 0.962, Auc 0.986, 417.1 samples/s cuda.
# On validation set: Loss 0.468, Accuracy 0.825, Auc 0.924.
# On test set: Loss 0.570, Accuracy 0.734, Auc 0.774.
# --------------------
# num of repeat: 70
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.984, 403.2 samples/s cuda.
# On validation set: Loss 0.526, Accuracy 0.800, Auc 0.871.
# On test set: Loss 0.568, Accuracy 0.755, Auc 0.760.
# --------------------
# num of repeat: 71
# --------------------
# On training set: Loss 0.356, Accuracy 0.962, Auc 0.973, 398.0 samples/s cuda.
# On validation set: Loss 0.547, Accuracy 0.775, Auc 0.857.
# On test set: Loss 0.593, Accuracy 0.713, Auc 0.782.
# --------------------
# num of repeat: 72
# --------------------
# On training set: Loss 0.359, Accuracy 0.968, Auc 0.987, 402.1 samples/s cuda.
# On validation set: Loss 0.586, Accuracy 0.675, Auc 0.788.
# On test set: Loss 0.612, Accuracy 0.681, Auc 0.752.
# --------------------
# num of repeat: 73
# --------------------
# On training set: Loss 0.359, Accuracy 0.955, Auc 0.967, 419.4 samples/s cuda.
# On validation set: Loss 0.540, Accuracy 0.750, Auc 0.837.
# On test set: Loss 0.592, Accuracy 0.734, Auc 0.797.
# --------------------
# num of repeat: 74
# --------------------
# On training set: Loss 0.384, Accuracy 0.949, Auc 0.966, 396.0 samples/s cuda.
# On validation set: Loss 0.555, Accuracy 0.725, Auc 0.787.
# On test set: Loss 0.562, Accuracy 0.755, Auc 0.771.
# --------------------
# num of repeat: 75
# --------------------
# On training set: Loss 0.328, Accuracy 0.987, Auc 0.993, 408.4 samples/s cuda.
# On validation set: Loss 0.561, Accuracy 0.750, Auc 0.821.
# On test set: Loss 0.596, Accuracy 0.691, Auc 0.751.
# --------------------
# num of repeat: 76
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.987, 397.0 samples/s cuda.
# On validation set: Loss 0.519, Accuracy 0.775, Auc 0.878.
# On test set: Loss 0.594, Accuracy 0.702, Auc 0.778.
# --------------------
# num of repeat: 77
# --------------------
# On training set: Loss 0.340, Accuracy 0.974, Auc 0.993, 423.9 samples/s cuda.
# On validation set: Loss 0.538, Accuracy 0.725, Auc 0.868.
# On test set: Loss 0.571, Accuracy 0.745, Auc 0.746.
# --------------------
# num of repeat: 78
# --------------------
# On training set: Loss 0.349, Accuracy 0.968, Auc 0.980, 366.3 samples/s cuda.
# On validation set: Loss 0.550, Accuracy 0.725, Auc 0.857.
# On test set: Loss 0.596, Accuracy 0.702, Auc 0.754.
# --------------------
# num of repeat: 79
# --------------------
# On training set: Loss 0.384, Accuracy 0.942, Auc 0.949, 413.8 samples/s cuda.
# On validation set: Loss 0.601, Accuracy 0.700, Auc 0.757.
# On test set: Loss 0.608, Accuracy 0.691, Auc 0.749.
# --------------------
# num of repeat: 80
# --------------------
# On training set: Loss 0.335, Accuracy 0.981, Auc 0.990, 422.8 samples/s cuda.
# On validation set: Loss 0.504, Accuracy 0.800, Auc 0.865.
# On test set: Loss 0.590, Accuracy 0.702, Auc 0.811.
# --------------------
# num of repeat: 81
# --------------------
# On training set: Loss 0.353, Accuracy 0.962, Auc 0.968, 371.6 samples/s cuda.
# On validation set: Loss 0.529, Accuracy 0.775, Auc 0.841.
# On test set: Loss 0.591, Accuracy 0.713, Auc 0.758.
# --------------------
# num of repeat: 82
# --------------------
# On training set: Loss 0.349, Accuracy 0.968, Auc 0.980, 409.5 samples/s cuda.
# On validation set: Loss 0.593, Accuracy 0.700, Auc 0.765.
# On test set: Loss 0.575, Accuracy 0.734, Auc 0.750.
# --------------------
# num of repeat: 83
# --------------------
# On training set: Loss 0.352, Accuracy 0.962, Auc 0.988, 371.6 samples/s cuda.
# On validation set: Loss 0.480, Accuracy 0.825, Auc 0.894.
# On test set: Loss 0.587, Accuracy 0.723, Auc 0.787.
# --------------------
# num of repeat: 84
# --------------------
# On training set: Loss 0.340, Accuracy 0.974, Auc 0.992, 381.5 samples/s cuda.
# On validation set: Loss 0.510, Accuracy 0.800, Auc 0.832.
# On test set: Loss 0.578, Accuracy 0.713, Auc 0.770.
# --------------------
# num of repeat: 85
# --------------------
# On training set: Loss 0.370, Accuracy 0.962, Auc 0.959, 413.8 samples/s cuda.
# On validation set: Loss 0.521, Accuracy 0.800, Auc 0.893.
# On test set: Loss 0.581, Accuracy 0.734, Auc 0.744.
# --------------------
# num of repeat: 86
# --------------------
# On training set: Loss 0.349, Accuracy 0.974, Auc 0.983, 425.1 samples/s cuda.
# On validation set: Loss 0.543, Accuracy 0.725, Auc 0.852.
# On test set: Loss 0.612, Accuracy 0.702, Auc 0.754.
# --------------------
# num of repeat: 87
# --------------------
# On training set: Loss 0.359, Accuracy 0.962, Auc 0.973, 410.6 samples/s cuda.
# On validation set: Loss 0.511, Accuracy 0.775, Auc 0.890.
# On test set: Loss 0.611, Accuracy 0.691, Auc 0.779.
# --------------------
# num of repeat: 88
# --------------------
# On training set: Loss 0.372, Accuracy 0.949, Auc 0.977, 402.1 samples/s cuda.
# On validation set: Loss 0.491, Accuracy 0.825, Auc 0.907.
# On test set: Loss 0.576, Accuracy 0.734, Auc 0.759.
# --------------------
# num of repeat: 89
# --------------------
# On training set: Loss 0.354, Accuracy 0.962, Auc 0.972, 416.0 samples/s cuda.
# On validation set: Loss 0.578, Accuracy 0.725, Auc 0.810.
# On test set: Loss 0.627, Accuracy 0.681, Auc 0.736.
# --------------------
# num of repeat: 90
# --------------------
# On training set: Loss 0.334, Accuracy 0.981, Auc 0.992, 407.4 samples/s cuda.
# On validation set: Loss 0.490, Accuracy 0.800, Auc 0.880.
# On test set: Loss 0.591, Accuracy 0.713, Auc 0.770.
# --------------------
# num of repeat: 91
# --------------------
# On training set: Loss 0.345, Accuracy 0.974, Auc 0.983, 410.6 samples/s cuda.
# On validation set: Loss 0.493, Accuracy 0.800, Auc 0.887.
# On test set: Loss 0.572, Accuracy 0.702, Auc 0.796.
# --------------------
# num of repeat: 92
# --------------------
# On training set: Loss 0.347, Accuracy 0.974, Auc 0.984, 375.1 samples/s cuda.
# On validation set: Loss 0.522, Accuracy 0.775, Auc 0.846.
# On test set: Loss 0.580, Accuracy 0.723, Auc 0.764.
# --------------------
# num of repeat: 93
# --------------------
# On training set: Loss 0.347, Accuracy 0.968, Auc 0.980, 422.8 samples/s cuda.
# On validation set: Loss 0.460, Accuracy 0.850, Auc 0.900.
# On test set: Loss 0.594, Accuracy 0.713, Auc 0.745.
# --------------------
# num of repeat: 94
# --------------------
# On training set: Loss 0.331, Accuracy 0.987, Auc 0.994, 406.3 samples/s cuda.
# On validation set: Loss 0.491, Accuracy 0.825, Auc 0.890.
# On test set: Loss 0.572, Accuracy 0.734, Auc 0.783.
# --------------------
# num of repeat: 95
# --------------------
# On training set: Loss 0.349, Accuracy 0.968, Auc 0.988, 416.0 samples/s cuda.
# On validation set: Loss 0.519, Accuracy 0.800, Auc 0.835.
# On test set: Loss 0.565, Accuracy 0.745, Auc 0.777.
# --------------------
# num of repeat: 96
# --------------------
# On training set: Loss 0.359, Accuracy 0.955, Auc 0.982, 374.2 samples/s cuda.
# On validation set: Loss 0.521, Accuracy 0.775, Auc 0.839.
# On test set: Loss 0.585, Accuracy 0.723, Auc 0.778.
# --------------------
# num of repeat: 97
# --------------------
# On training set: Loss 0.346, Accuracy 0.968, Auc 0.986, 406.3 samples/s cuda.
# On validation set: Loss 0.515, Accuracy 0.775, Auc 0.872.
# On test set: Loss 0.573, Accuracy 0.723, Auc 0.801.
# --------------------
# num of repeat: 98
# --------------------
# On training set: Loss 0.328, Accuracy 0.987, Auc 0.990, 366.3 samples/s cuda.
# On validation set: Loss 0.497, Accuracy 0.800, Auc 0.863.
# On test set: Loss 0.580, Accuracy 0.723, Auc 0.791.
# --------------------
# num of repeat: 99
# --------------------
# On training set: Loss 0.354, Accuracy 0.962, Auc 0.988, 404.2 samples/s cuda.
# On validation set: Loss 0.481, Accuracy 0.850, Auc 0.842.
# On test set: Loss 0.597, Accuracy 0.713, Auc 0.735.
# --------------------
# One layer without smote with mask with early stopping under k-fold cv best model:
# --------------------
# On training set: Loss 0.353, Accuracy 0.965, Auc 0.980, 403.1 samples/s cuda.
# On validation set: Loss 0.525, Accuracy 0.773, Auc 0.859.
# On test set: Loss 0.587, Accuracy 0.716, Auc 0.766.

# %%
t = time.localtime()
print(str(t.tm_hour)+':'+str(t.tm_min))
# Out:
# 0:30
